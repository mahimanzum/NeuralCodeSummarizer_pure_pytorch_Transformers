# %%
import torch
print(torch.__version__)
#!pip install torchtext==0.5
#!pip install -U torch==1.5
#!pip install tokenizers
# !pip install nbresuse

# %%
#!ls ../data/ncs_preprocessed_data/train-ncs/
#!pip install tokenizers
#tokenizer.decode(tokenizer.encode("hello there").ids)

# !git clone https://github.com/NVIDIA/apex
# !cd apex

# %%
#ls ../data/ncs_preprocessed_data/train-ncs/
# !cd apex;pip install -v --no-cache-dir ./
#!print(src_tokenizer)

# %%
print(src_tokenizer.encode('<s> </s> <pad>').ids)
print(src_tokenizer.encode(' hi there ').ids)
print(tgt_tokenizer.decode(src_tokenizer.encode(' hi there ').ids))

# %%
from apex import amp
from tokenizers import ByteLevelBPETokenizer
src_tokenizer = ByteLevelBPETokenizer()


src_tokenizer.train(["../data/ncs_preprocessed_data/train-ncs/code.original_subtoken"], vocab_size=30000, special_tokens=[
    "<s>",
    "<pad>",
    "</s>",
    "<unk>",
    "<mask>"])

tgt_tokenizer = ByteLevelBPETokenizer()
tgt_tokenizer.train(["../data/ncs_preprocessed_data/train-ncs/javadoc.original"], vocab_size=20000, special_tokens=[
    "<s>",
    "<pad>",
    "</s>",
    "<unk>",
    "<mask>"])

# %%
vars(src_tokenizer)

# %%
print(src_tokenizer.encode('<s> </s> <pad> <unk>').ids) #[0, 225, 2, 225, 1]
print(src_tokenizer.encode(' hi there ').ids)

print(tgt_tokenizer.encode('<s> </s> <pad> <unk>').ids) #[0, 225, 2, 225, 1]
print(tgt_tokenizer.encode(' hi there ').ids)

print(src_tokenizer.decode([13000]))
print(src_tokenizer)
print(tgt_tokenizer)

# %%
from torch.utils.data import Dataset, DataLoader
from joblib import Parallel, delayed
import threading
import linecache
linecache.clearcache()
import subprocess
import os
from tqdm import tqdm
import torch

MAX_SRC_LEN = 200
MAX_TGT_LEN = 50


def pad_sequences(x, max_len):
    padded = torch.ones((max_len), dtype=torch.long)
    if len(x) > max_len: padded[:] = torch.tensor(x[:max_len] , dtype=torch.long)
    else: padded[:len(x)] = torch.tensor(x, dtype=torch.long)
    return padded

class LazyDataset(Dataset):
    def __init__(self, src_tokenizer,tgt_tokenizer, src_path, tgt_path, max_len_src = MAX_SRC_LEN,max_len_tgt=MAX_TGT_LEN):
        self.src_path = src_path
        self.tgt_path = tgt_path
        self.max_len_src = max_len_src
        self.max_len_tgt = max_len_tgt
        self.src_tokenizer = src_tokenizer
        self.tgt_tokenizer = tgt_tokenizer
        self.num_entries = sum(1 for line in open(src_path))
        self.target_entries = sum(1 for line in open(tgt_path))
        print(self.num_entries, self.target_entries)
        assert self.num_entries == self.target_entries
        
            
    def __getitem__(self, idx):
        x = self.src_tokenizer.encode("<s>"+linecache.getline(self.src_path, idx + 1).strip()+"</s>").ids
        y = self.tgt_tokenizer.encode("<s>"+linecache.getline(self.tgt_path, idx + 1).strip()+"</s>").ids
        
        return torch.tensor(pad_sequences(x,self.max_len_src), dtype=torch.long),torch.tensor(pad_sequences(y,self.max_len_tgt), dtype=torch.long) 
    
    def __len__(self):
        return self.num_entries

train_dataset = LazyDataset(src_tokenizer, tgt_tokenizer, '../data/ncs_preprocessed_data/train-ncs/code.original_subtoken',
                            '../data/ncs_preprocessed_data/train-ncs/javadoc.original')

# %%
test_dataset = LazyDataset(src_tokenizer, tgt_tokenizer, '../data/ncs_preprocessed_data/test/code.original_subtoken',
                            '../data/ncs_preprocessed_data/test/javadoc.original')

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import spacy
import numpy as np

import random
import math
import time

SEED = 1234

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
#!conda install spacy
#!python -m spacy.en.download
#!spacy download en
#spacy_en = spacy.load('en')

#!pip install spacy

# %%
'''
def tokenize_en(text):
    """
    Tokenizes English text from a string into a list of strings
    """
    return [tok.text for tok in spacy_en.tokenizer(text)]
'''

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
class Encoder(nn.Module):
    def __init__(self, 
                 input_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim,
                 dropout, 
                 device,
                 max_length = MAX_SRC_LEN):
        super().__init__()

        self.device = device
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([EncoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim,
                                                  dropout, 
                                                  device) 
                                     for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src len]
        #src_mask = [batch size, src len]
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
        
        #pos = [batch size, src len]
        
        src = self.dropout((self.tok_embedding(src) * self.scale) + self.pos_embedding(pos))
        
        #src = [batch size, src len, hid dim]
        
        for layer in self.layers:
            src = layer(src, src_mask)
            
        #src = [batch size, src len, hid dim]
            
        return src

class EncoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim,  
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src len, hid dim]
        #src_mask = [batch size, src len]
                
        #self attention
        _src, _ = self.self_attention(src, src, src, src_mask)
        
        #dropout, residual connection and layer norm
        src = self.self_attn_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        #positionwise feedforward
        _src = self.positionwise_feedforward(src)
        
        #dropout, residual and layer norm
        src = self.ff_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        return src
class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, dropout, device):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        self.head_dim = hid_dim // n_heads
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value, mask = None):
        
        batch_size = query.shape[0]
        
        #query = [batch size, query len, hid dim]
        #key = [batch size, key len, hid dim]
        #value = [batch size, value len, hid dim]
                
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        
        #Q = [batch size, query len, hid dim]
        #K = [batch size, key len, hid dim]
        #V = [batch size, value len, hid dim]
                
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        
        #Q = [batch size, n heads, query len, head dim]
        #K = [batch size, n heads, key len, head dim]
        #V = [batch size, n heads, value len, head dim]
                
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        
        #energy = [batch size, n heads, query len, key len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = torch.softmax(energy, dim = -1)
                
        #attention = [batch size, n heads, query len, key len]
                
        x = torch.matmul(self.dropout(attention), V)
        
        #x = [batch size, n heads, query len, head dim]
        
        x = x.permute(0, 2, 1, 3).contiguous()
        
        #x = [batch size, query len, n heads, head dim]
        
        x = x.view(batch_size, -1, self.hid_dim)
        
        #x = [batch size, query len, hid dim]
        
        x = self.fc_o(x)
        
        #x = [batch size, query len, hid dim]
        
        return x, attention
    
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, seq len, hid dim]
        
        x = self.dropout(torch.relu(self.fc_1(x)))
        
        #x = [batch size, seq len, pf dim]
        
        x = self.fc_2(x)
        
        #x = [batch size, seq len, hid dim]
        
        return x
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = MAX_TGT_LEN):
        super().__init__()
        
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask):
        
        #trg = [batch size, trg len]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, trg len]
        #src_mask = [batch size, src len]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
                            
        #pos = [batch size, trg len]
            
        trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
                
        #trg = [batch size, trg len, hid dim]
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask)
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        output = self.fc_out(trg)
        
        #output = [batch size, trg len, output dim]
            
        return output, attention
class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask):
        
        #trg = [batch size, trg len, hid dim]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, trg len]
        #src_mask = [batch size, src len]
        
        #self attention
        _trg, _ = self.self_attention(trg, trg, trg, trg_mask)
        
        #dropout, residual connection and layer norm
        trg = self.self_attn_layer_norm(trg + self.dropout(_trg))
            
        #trg = [batch size, trg len, hid dim]
            
        #encoder attention
        _trg, attention = self.encoder_attention(trg, enc_src, enc_src, src_mask)
        
        #dropout, residual connection and layer norm
        trg = self.enc_attn_layer_norm(trg + self.dropout(_trg))
                    
        #trg = [batch size, trg len, hid dim]
        
        #positionwise feedforward
        _trg = self.positionwise_feedforward(trg)
        
        #dropout, residual and layer norm
        trg = self.ff_layer_norm(trg + self.dropout(_trg))
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return trg, attention
    
class Seq2Seq(nn.Module):
    def __init__(self, 
                 encoder, 
                 decoder, 
                 src_pad_idx, 
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device
        
    def make_src_mask(self, src):
        
        #src = [batch size, src len]
        
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)

        #src_mask = [batch size, 1, 1, src len]

        return src_mask
    
    def make_trg_mask(self, trg):
        
        #trg = [batch size, trg len]
        
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device = self.device)).bool()
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        return trg_mask

    def forward(self, src, trg):
        
        #src = [batch size, src len]
        #trg = [batch size, trg len]
                
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        
        #src_mask = [batch size, 1, 1, src len]
        #trg_mask = [batch size, 1, trg len, trg len]
        
        enc_src = self.encoder(src, src_mask)
        
        #enc_src = [batch size, src len, hid dim]
                
        output, attention = self.decoder(trg, enc_src, trg_mask, src_mask)
        
        #output = [batch size, trg len, output dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return output, attention

# %%
INPUT_DIM = 30000
OUTPUT_DIM = 20000



HID_DIM = 256
ENC_LAYERS = 6
DEC_LAYERS = 6
ENC_HEADS = 8
DEC_HEADS = 8
ENC_PF_DIM = 512
DEC_PF_DIM = 512
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1

enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT, 
              device)

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)

# %%
model = Seq2Seq(enc, dec, 1, 1, device).to(device)

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')

# %%
def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

# %%
model.apply(initialize_weights)
#LEARNING_RATE = 0.0005
LEARNING_RATE = 0.00005

optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)
criterion = nn.CrossEntropyLoss(ignore_index = 1)

# %%
from tqdm import tqdm
def train(model, dataset, optimizer, criterion, clip):
    
    model.train()
    
    epoch_loss = 0
    for (src_, trg_) in tqdm(dataset):
        
        optimizer.zero_grad()

        src, trg = src_.to(device), trg_.to(device)
        output, _ = model(src, trg[:,:-1])

        #output = [batch size, trg len - 1, output dim]
        #trg = [batch size, trg len]
        #print(trg.shape)
        #print(output.shape)
        output_dim = output.shape[-1]

        output = output.contiguous().view(-1, output_dim) #[:, :-1, :]
        trg = trg[:,1:].contiguous().view(-1)

        #output = [batch size * trg len - 1, output dim]
        #trg = [batch size * trg len - 1]
        #print(trg.shape)
        #print(output.shape)
        loss = criterion(output, trg)
        with amp.scale_loss(loss, optimizer) as scaled_loss:
            scaled_loss.backward()
        #loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
        
        optimizer.step()
        epoch_loss += loss.item()
        #print(f'\tTrain Loss: {loss.item():.3f} | Train PPL: {math.exp(loss.item()):7.3f}')

        
    return epoch_loss / len(dataset)

# %%
def evaluate(model,dataset,criterion):
    
    model.eval()
    epoch_loss = 0
    with torch.no_grad():
        for (src_, trg_) in tqdm(dataset):
            src, trg = src_.to(device), trg_.to(device)
            output, _ = model(src, trg[:,:-1])

            output_dim = output.shape[-1]

            output = output.contiguous().view(-1, output_dim) #[:, :-1, :]
            trg = trg[:,1:].contiguous().view(-1)
            loss = criterion(output, trg)
            epoch_loss += loss.item()
        
    return epoch_loss / len(dataset)

def give_pred(model, tokens, device, max_len=50):
    model.eval()
    
    src_indexes = tokens
    #print(tokens.size())
    src_tensor = torch.LongTensor(src_indexes).to(device)
    
    src_mask = model.make_src_mask(src_tensor)
    with torch.no_grad():
        enc_src = model.encoder(src_tensor, src_mask)

    trg_indexes = torch.zeros((tokens.size()[0], 1), dtype = torch.long)
    trg_indexes = trg_indexes.tolist()
    #print(trg_indexes)
    #print(trg_indexes.size())
    
    for i in range(max_len):
        #print(len(trg_indexes),len(trg_indexes[0]))
        #trg_tensor = torch.LongTensor(pad_sequences(trg_indexes, 50)).unsqueeze(0).to(device)
        trg_tensor = torch.LongTensor(trg_indexes).to(device)
        #print("in loop", trg_tensor.size())
        trg_mask = model.make_trg_mask(trg_tensor)
        #print(trg_mask)
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask)
        
        #print("out shape", output.size())
        
        
        
        for idx in range(len(trg_indexes)):
            #print("shape here = ", output[i][-1].size())
            #print(output[idx][-1].argmax().item())
            trg_indexes[idx].append(output[idx][-1].argmax().item())
            
        
        #pred_token = output.argmax(2)[:,-1].item()
        #print(output[0][-1].argmax())
        #print(pred_token)
        #trg_indexes.append(pred_token)

        #if pred_token == 2:
        #    break
    #print(len(trg_indexes),len(trg_indexes[0]))
    return trg_indexes

def calculate_blue(model,test_ds, device, max_len = 50):
    model.eval()
    sum_blue = 0
    data_count = 0
    for (src_, trg_) in tqdm(test_ds):
        hypothesis = give_pred(model,src_, device, max_len = 50)
        reference = trg_.tolist()
        #there may be several references
        for i in range(src_.size()[0]):
            sum_blue += nltk.translate.bleu_score.sentence_bleu([reference[i]], hypothesis[i])
            data_count+=1
        #print(sum_blue/data_count)
        #print(data_count)
    return sum_blue/data_count

'''
import warnings
import nltk
warnings.filterwarnings('ignore')

N_EPOCHS = 20
CLIP = 1

BATCH_SIZE = 280
EVAL_BATCH_SIZE = 500

train_dataset = DataLoader(train_dataset, batch_size = BATCH_SIZE, num_workers=5,
                     drop_last=True,
                     shuffle=True)

test_dataset = DataLoader(test_dataset, batch_size = EVAL_BATCH_SIZE, num_workers=5,
                     drop_last=True,
                     shuffle=False)


calculate_blue(model,test_dataset, device, max_len = 50)
'''

# %%
'''
for (src_, trg_) in test_dataset:
    for i in range(src_.size()[0]):
        print(src_.size())
        hypothesis = give_pred(model,src_[i], device, max_len = 50)
        reference = trg_[i].tolist()
        #there may be several references
        sum_blue = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis)
        #data_count+=1
'''

# %%
import warnings
import nltk
warnings.filterwarnings('ignore')

N_EPOCHS = 300
CLIP = 1

BATCH_SIZE = 215
EVAL_BATCH_SIZE = 850

train_dataset = DataLoader(train_dataset, batch_size = BATCH_SIZE, num_workers=5,
                     drop_last=True,
                     shuffle=True)

test_dataset = DataLoader(test_dataset, batch_size = EVAL_BATCH_SIZE, num_workers=5,
                     drop_last=True,
                     shuffle=False)


#scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, len(train_dataset))
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer)



def epoch_time(start_time, end_time):
    elapsed_time = end_time - start_time
    elapsed_mins = int(elapsed_time / 60)
    elapsed_secs = int(elapsed_time - (elapsed_mins * 60))
    return elapsed_mins, elapsed_secs

best_valid_loss = float('inf')

opt_level = 'O1'
model, optimizer = amp.initialize(model, optimizer, opt_level=opt_level)
    

for epoch in range(N_EPOCHS):
    
    start_time = time.time()
    train_loss = train(model, train_dataset, optimizer, criterion, CLIP)
    #scheduler.step()
    scheduler.step(train_loss)
    valid_loss = evaluate(model, test_dataset, criterion)
    
    blue_score = calculate_blue(model,test_dataset, device, max_len = 50)
    end_time = time.time()
    
    epoch_mins, epoch_secs = epoch_time(start_time, end_time)
    
    
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(model.state_dict(), 'tut6-model.pt')
    
    
    print(f'Epoch: {epoch+1:02} | Time: {epoch_mins}m {epoch_secs}s')
    print(f'\tTrain Loss: {train_loss:.3f} | Train PPL: {math.exp(train_loss):7.3f}')
    print(f'\t Val. Loss: {valid_loss:.3f} |  Val. PPL: {math.exp(valid_loss):7.3f}')
    print("validation blue score = ",blue_score*100)
    '''
    annealing
    Epoch: 14 | Time: 1m 43s
    Train Loss: 4.060 | Train PPL:  57.988
    
    Epoch: 07 | Time: 1m 58s
	Train Loss: 4.715 | Train PPL: 111.645
	 Val. Loss: 4.773 |  Val. PPL: 118.230
    '''

# %%
train_dataset = LazyDataset(src_tokenizer, tgt_tokenizer, '../data/ncs_preprocessed_data/train-ncs/code.original_subtoken',
                            '../data/ncs_preprocessed_data/train-ncs/javadoc.original')


train_dataset = DataLoader(train_dataset, batch_size = 101, num_workers=10,
                     drop_last=True,
                     shuffle=True)
for (src_, trg_) in tqdm(train_dataset):
    src, trg = src_.to(device), trg_.to(device)
    print(src[0].size())

# %%
#load and save here

# Save checkpoint
checkpoint = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict(),
    'amp': amp.state_dict()
}
torch.save(checkpoint, '../models/big_checkpoint_corrected_600_loss2.pt')

# %%
# Restore
opt_level = 'O1'
model = Seq2Seq(enc, dec, 1, 1, device).to(device)
LEARNING_RATE = 0.0005

optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)

checkpoint = torch.load('../models/big_checkpoint_corrected_600_loss1.pt')

model, optimizer = amp.initialize(model, optimizer, opt_level=opt_level)
model.load_state_dict(checkpoint['model'])
optimizer.load_state_dict(checkpoint['optimizer'])
amp.load_state_dict(checkpoint['amp'])


import warnings
import nltk
warnings.filterwarnings('ignore')

N_EPOCHS = 20
CLIP = 1

BATCH_SIZE = 280
EVAL_BATCH_SIZE = 500

train_dataset = DataLoader(train_dataset, batch_size = BATCH_SIZE, num_workers=5,
                     drop_last=True,
                     shuffle=True)

test_dataset = DataLoader(test_dataset, batch_size = EVAL_BATCH_SIZE, num_workers=5,
                     drop_last=True,
                     shuffle=False)

# %%
def give_pred(model, tokens, device, max_len=50):
    model.eval()
    
    src_indexes = tokens
    #print(tokens.size())
    src_tensor = torch.LongTensor(src_indexes).to(device)
    
    src_mask = model.make_src_mask(src_tensor)
    with torch.no_grad():
        enc_src = model.encoder(src_tensor, src_mask)

    trg_indexes = torch.zeros((tokens.size()[0], 1), dtype = torch.long)
    trg_indexes = trg_indexes.tolist()
    #print(trg_indexes)
    #print(trg_indexes.size())
    
    for i in range(max_len):
        #print(len(trg_indexes),len(trg_indexes[0]))
        #trg_tensor = torch.LongTensor(pad_sequences(trg_indexes, 50)).unsqueeze(0).to(device)
        trg_tensor = torch.LongTensor(trg_indexes).to(device)
        #print("in loop", trg_tensor.size())
        trg_mask = model.make_trg_mask(trg_tensor)
        #print(trg_mask)
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask)
        
        #print("out shape", output.size())
        
        
        
        for idx in range(len(trg_indexes)):
            #print("shape here = ", output[i][-1].size())
            #print(output[idx][-1].argmax().item())
            trg_indexes[idx].append(output[idx][-1].argmax().item())
            
        
        #pred_token = output.argmax(2)[:,-1].item()
        #print(output[0][-1].argmax())
        #print(pred_token)
        #trg_indexes.append(pred_token)

        #if pred_token == 2:
        #    break
    #print(len(trg_indexes),len(trg_indexes[0]))
    return trg_indexes

def calculate_blue(model,test_ds, device, max_len = 50):
    model.eval()
    sum_blue = 0
    data_count = 0
    for (src_, trg_) in tqdm(test_ds):
        hypothesis = give_pred(model,src_, device, max_len = 50)
        reference = trg_.tolist()
        #there may be several references
        for i in range(src_.size()[0]):
            sum_blue += nltk.translate.bleu_score.sentence_bleu([reference[i]], hypothesis[i])
            data_count+=1
        print(sum_blue/data_count)
        print(data_count)
    return sum_blue/data_count

calculate_blue(model,test_dataset, device, max_len = 50)

# %%
def translate_sentence(sentence, model, device, max_len = 50):    
    model.eval()
        # add <s> </s>
    #    "<s> "+linecache.getline(self.src_path, idx + 1).strip()+" </s>"
    src_indexes = pad_sequences(src_tokenizer.encode("<s>"+sentence.strip()+ "</s>").ids, 150)
    #print(src_indexes)
    #torch.tensor(pad_sequences(x,self.max_len_src), dtype=torch.long)
    src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
    #src_tensor = torch.LongTensor(src_indexes).unsqueeze(0).to(device)
    
    src_mask = model.make_src_mask(src_tensor)
    #print(src_mask)
    with torch.no_grad():
        enc_src = model.encoder(src_tensor, src_mask)

    trg_indexes = [0]
    
    for i in range(max_len):

        #trg_tensor = torch.LongTensor(pad_sequences(trg_indexes, 50)).unsqueeze(0).to(device)
        trg_tensor = torch.LongTensor(trg_indexes).unsqueeze(0).to(device)
        #print(trg_tensor)
        trg_mask = model.make_trg_mask(trg_tensor)
        #print(trg_mask)
        with torch.no_grad():
            output, attention = model.decoder(trg_tensor, enc_src, trg_mask, src_mask)
        
        pred_token = output.argmax(2)[:,-1].item()
        #print(output[0][-1].argmax())
        #print(pred_token)
        trg_indexes.append(pred_token)

        if pred_token == 2:
            break
    print(trg_indexes)
    trg_tokens = [tgt_tokenizer.decode([i]) for i in trg_indexes]
    
    return trg_tokens, attention

# %%
s  = "public static List < String > read Lines ( File file ) throws IO Exception { return read Lines ( file , Charset . default Charset ( ) ) ; }"
#s = "private void update Rating Choice ( ) { int current = m ch Rating . get Selected Index ( ) ; m ch Rating . remove All Items ( ) ; Faction Record f Rec = ( Faction Record ) m ch Subfaction . get Selected Item ( ) ; if ( f Rec == null ) { f Rec = ( Faction Record ) m ch Faction . get Selected Item ( ) ; } Array List < String > rating Levels = f Rec . get Rating Levels ( ) ; if ( rating Levels . is Empty ( ) ) { rating Levels = f Rec . get Rating Level System ( ) ; } if ( rating Levels . size ( ) > NUM ) { for ( int i = rating Levels . size ( ) - NUM ; i >= NUM ; i -- ) { m ch Rating . add Item ( rating Levels . get ( i ) ) ; } } if ( current < NUM && m ch Rating . get Item Count ( ) > NUM ) { m ch Rating . set Selected Index ( NUM ) ; } else { m ch Rating . set Selected Index ( Math . min ( current , m ch Rating . get Item Count ( ) - NUM ) ) ; } }"
#s = "public static boolean memory Is Low ( ) { return available Memory ( ) * NUM < RUNTIME . total Memory ( ) * NUM ; }"
out, _ = translate_sentence(s, model, 'cuda')
print(out)

src_tokenizer.decode([352])

# %%
# %matplotlib inline
def display_attention(sentence, translation, attention, n_heads = 8, n_rows = 4, n_cols = 2):
    
    assert n_rows * n_cols == n_heads
    
    fig = plt.figure(figsize=(15,25))
    
    for i in range(n_heads):
        
        ax = fig.add_subplot(n_rows, n_cols, i+1)
        
        _attention = attention.squeeze(0)[i].cpu().detach().numpy()

        cax = ax.matshow(_attention, cmap='bone')

        ax.tick_params(labelsize=12)
        ax.set_xticklabels(['']+['<sos>']+[t.lower() for t in sentence]+['<eos>'], 
                           rotation=45)
        ax.set_yticklabels(['']+translation)

        ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
        ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()
    plt.close()
    
translation, attention = translate_sentence(s, model, 'cuda')
display_attention(s, translation, attention)

# %%
import nltk

hypothesis = ['It', 'is', 'a', 'cat', 'at', 'room']
reference = ['It', 'is', 'a', 'cat', 'inside', 'the', 'room']
#there may be several references
BLEUscore = nltk.translate.bleu_score.sentence_bleu([reference], hypothesis)
print(BLEUscore)

# %%
print(tgt_tokenizer.decode([225, 2, 225, 1]))
print(tgt_tokenizer.decode(tgt_tokenizer.encode("hello there").ids))
print(tgt_tokenizer.encode("<s> hello there <pad> <pad>").ids)
print(tgt_tokenizer.encode('<pad>').ids)
tgt_tokenizer.decode([10304])

# %%
# !pip install tqdm

# %%
# !head -3 ../data/ncs_preprocessed_data/train-ncs/code.original_subtoken

# %%
# !head -3 ../data/ncs_preprocessed_data/train-ncs/javadoc.original

# %%
??tgt_tokenizer

# %%
x = torch.Tensor.new_full(50,20000, dtype=torch.long)

# %%
src_tokenizer

# %%
torch.tensor.new_full((3, 4), 3.141592)

# %%
import gc
gc.collect()

# %%
# !nvidia-smi

# %%
len(tgt_tokenizer.encode("reads the contents of a file line by line to a list of strings using the default encoding for the vm . the file is always closed .").ids)

# %%
dataset = DataLoader(train_dataset, batch_size = 10, num_workers=10,
                     drop_last=True,
                     shuffle=True)

for (src_, trg_) in dataset:
    print(src_[0])
    break

# %%
wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1B8EI5pQUswtUuiYwiInxCb02d5t1NHKH' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1B8EI5pQUswtUuiYwiInxCb02d5t1NHKH" -O ncs_big.7z && rm -rf /tmp/cookies.txt

# %%
sum_blue +=compute_bleu([reference], hypothesis, smooth=True)[0]

# %%
from google_bleu import compute_bleu

# %%
import pickle
ref = pickle.load(open('ref.pkl', 'rb'))

# %%
from pprint import pprint
pprint(ref)
# Out:
# {0: ['returns a 0 - based depth within the object graph of the current object '
#      'being serialized .'],
#  1: ['checks whether the scheme alters the training dataset during building . '
#      'if the scheme needs to modify the data it should take a copy of the '
#      'training data . currently checks for changes to header structure , '
#      'number of instances , order of instances , instance weights .'],
#  2: ['compute the union size of two bit sets .'],
#  3: ['tests local candidates with remote version in the middle on key 2 .'],
#  4: ['actions to perform when the user has closed the dialog with the ok '
#      'button .'],
#  5: ['prints out the classifier .'],
#  6: ['returns a new sector whose angles are the extre mes of the this sector '
#      "and another . the new sector ' s minimum latitude and longitude will be "
#      "the minimum of the two sectors . the new sector ' s maximum latitude and "
#      'longitude will be the maximum of the two sectors . the sectors are '
#      'assumed to be normalized to + / - 90 degrees latitude and + / - 180 '
#      'degrees longitude . the result of the operation is undefined if they are '
#      'not .'],
#  7: ['checks if is double values are equal .'],
#  8: ['integer value of a positive bigdecimal'],
#  9: ['main recursive method to examine the directory hierarchy .'],
#  10: ['get a sorted array containing all column values for a given tuple '
#       'iterator and field .'],
#  11: ['divide with invalid rounding mode'],
#  12: ["receives notification of a change to the plot ' s dataset . the axis "
#       'ranges are updated if necessary .'],
#  13: ['invoke the on scheduler ( ) in isched uler directly as a library'],
#  14: ['returns true if specified type is java . lang . string'],
#  15: ['api method . returns an entry for the source indexed by the user and '
#       "the url . this method creates it if it didn ' t already exist ."],
#  16: ['validates the given sql statement where its position in the list of '
#       'statement is the given index . this method does not validate sql syntax '
#       '.'],
#  17: ['converts to object array .'],
#  18: ['is this logger instance enabled for the finest level ?'],
#  19: ['remove an used up mis si le from an attacking player .'],
#  20: ['creates a new matcher for running co ap over tcp .'],
#  21: ['recursively does the work'],
#  22: ['ask to the user for ret yp ing the pass code just entered before saving '
#       'it as the current pass code .'],
#  23: ['rolls back the worker thread creation . - removes worker from workers , '
#       'if present - decrements worker count - re checks for termination , in '
#       'case the existence of this worker was holding up termination'],
#  24: ['insert functionality test test insert 4 ( ) . tests insert . . . select '
#       'with expressions in select query'],
#  25: ['writes one entry to the local id map on disk .'],
#  26: ['receive notification of the end of an element .'],
#  27: ['send a fatal error log message'],
#  28: ['leaves can be used for many - to - many relations'],
#  29: ['returns a string representation of this vector . note that this string '
#       'representation shows the bit of index 0 at the leftmost position .'],
#  30: ['validate the uri characters within a specific component . the component '
#       "must be performed after escape encoding . or it doesn ' t include "
#       "escaped characters . it ' s not that much strict , gener ous . the "
#       'strict validation might be performed before being called this method .'],
#  31: ['build the final bitmap - pieces to draw in animation'],
#  32: ['de - registers a previously - registered virtual - machine shutdown '
#       'hook .'],
#  33: ['a seperate thread collects our input so that we can block in the do '
#       'continue on the main thread and then allow the user to interrupt us via '
#       'keyboard input on this thread . we built the stupid thing in this '
#       "manner , since readline ( ) will block no matter what and if we ' quit "
#       "' we can ' t seem to kill this thread . . close ( ) doesn ' t work and "
#       'thread . stop ( ) , etc . all fail to do the job . thus we needed to '
#       'take a request response approach so that we only block when requested '
#       'to do so .'],
#  34: ['bounds the current scroll if necessary'],
#  35: ['adds the statistics encapsulated in the supplied evaluation object into '
#       'this one . does not perform any checks for compatibility between the '
#       'supplied evaluation object and this one .'],
#  36: ['scans all sites until all volumes involved in the recover point '
#       'protection are visible'],
#  37: ['this method is called immediately following cache creation in the '
#       'spawned process , but prior to setting the running flag in the status '
#       'file . so the spawning process will block until this method completes '
#       '.'],
#  38: ['update the content of the outline view .'],
#  39: ['paints the image on the window .'],
#  40: ['returns true if , at this time , the object will accept a connection '
#       'with respect to the named event'],
#  41: ['it returns true if the attribute is prefixed ( used the " : " character '
#       ') .'],
#  42: ['release a non - shard - specific connection .'],
#  43: ['adds a collection of actions to the quick action view'],
#  44: ['adds a simple renderer to the multiple renderer .'],
#  45: ['copies stream , fires progress events by listener , can be interrupted '
#       'by listener .'],
#  46: ['calculates the needed angle for a given value'],
#  47: ['returns a buffer to the pool , throwing away old buffers if the pool '
#       'would exceed its allo tted size .'],
#  48: ['creates a new instance .'],
#  49: ['append string of the given char seq to this char seq'],
#  50: ['this method processes all of the http get requests routed to the '
#       'servlet by the web container . this method loops through the lists of '
#       'videos that have been sent to it and generates a plain / text list of '
#       'the videos that is sent back to the client .'],
#  51: ["change the stored state value and do notification , but don ' t change "
#       'anything in the hardware'],
#  52: ['test for get order ( ) method'],
#  53: ['formats and logs a message with a throwable .'],
#  54: ['constructs the redis queue sorted set key name given a queue name , '
#       'shard id and priority .'],
#  55: ['decodes the string into specified charset'],
#  56: ['adds specified domain name to the list of restricted domains'],
#  57: ['create a new read lock from the given lock'],
#  58: ['tests fail : always returns false , failing statements commented out . '
#       'feature only partially implemented . missing : test positive case not '
#       'supported .'],
#  59: ['computes the " interface hash " of the stub / skeleton pair for this '
#       'remote implementation class . this is the 64 - bit value used to '
#       'enforce compatibility between a stub class and a skeleton class in the '
#       'jdk 1 . 1 version of the jr mp stub / skeleton protocol . it is '
#       'calculated using the first 64 bits of an sha digest . the digest is of '
#       'a stream consisting of the following data : ( int ) stub version number '
#       ', always 1 for each remote method , in order of operation number : ( '
#       'utf - 8 ) method name ( utf - 8 ) method descriptor for each declared '
#       'exception , in alphabetical name order : ( utf - 8 ) name of exception '
#       'class ( where " utf - 8 " includes a 16 - bit length prefix as written '
#       'by java . io . dataoutput . write utf ) .'],
#  60: ['copy the contents of the given byte array to the given outputstream . '
#       'leaves the stream open when done .'],
#  61: ["returns true whether this page doesn ' t contain items , returns false "
#       'if it does .'],
#  62: ['decodes a frame if needed .'],
#  63: ['encode parts of the message using text compaction as described in iso / '
#       'iec 154 38 : 2001 ( e ) , chapter 4 . 4 . 2 .'],
#  64: ['check to see if a string is a valid ncname according to [ 4 ] from the '
#       'xml namespaces 1 . 0 recommendation'],
#  65: ['appends the specified element to the end of this list .'],
#  66: ['prepare the dataset required for running test cases'],
#  67: ['returns array of service registrar created from the proxy reg set'],
#  68: ['check if the supplied value is a valid value .'],
#  69: ['find a new primary , adding any failed servers we encounter to the '
#       'excluded servers list first we try to make a backup server the primary '
#       ', but if run out of backup servers we will try to find a new server .'],
#  70: ['creates a new journal that omits redundant information . this replaces '
#       'the current journal if it exists .'],
#  71: ['removes the recurrence from persistant store .'],
#  72: ['copy nodelist members into this nodelist , adding in document order . '
#       "if a node is null , don ' t add it ."],
#  73: ["fetches data if it hasn ' t been fetched in a while ."],
#  74: ['introduced in dom level 2 . creates an empty documenttype node .'],
#  75: ['services a commandline request .'],
#  76: ['serializes this nested object into byte [ ]'],
#  77: ['returns first enum constant found in at space - separated list of style '
#       'names .'],
#  78: ['sce mp e gn ext av cr pa u - skip one video frame'],
#  79: ['given a set of exportmask uris , return a map of exportmask uri to '
#       'exportmask object'],
#  80: ['insert an entry at this index .'],
#  81: ['write a graphic to the printout . this was not in the original class , '
#       'but was added afterwards by ke vin di c ker son . it is a copy of the '
#       'write , but without the scaling . the image is positioned on the right '
#       'side of the paper , at the current height .'],
#  82: ['put the source tree root node in the document cache . todo : this '
#       'function needs to be a lot more sophisticated .'],
#  83: ['used to communicate a progress update between a plugin tool and the '
#       'main whitebox user interface .'],
#  84: ['copy a input resource to a output resource'],
#  85: ['fade audio file so x < path > outfile fade < type > < fa de in length > '
#       '< stop time > < fa de out length >'],
#  86: ['todo : to be implemented'],
#  87: ['for all the classes , loads all properties from each class annotations '
#       'for the given platform .'],
#  88: ['add a number to zero'],
#  89: ['fixes the gps timestamp in exif .'],
#  90: ['check if a cell consumes the specified event type .'],
#  91: ['read a single character . this method will block until a character is '
#       'available , an i / o error occurs , or the end of the stream is reached '
#       '. subclasses that intend to support efficient single - character input '
#       'should override this method .'],
#  92: ['this function is used to plot the y axis and its breakdown with value . '
#       'uses draw line ( ) method to create the y axis and lines to show '
#       'breakdown of y axis and draw text ( ) method to plot labels related '
#       'with break downs'],
#  93: ['get running - maximum time - delta , in nanoseconds .'],
#  94: ['prints a file with the native desktop printing facility , using the '
#       "associated application ' s print command ."],
#  95: ['extends the existing ground ings with the alternative ground ings'],
#  96: ['this will attempt to read string matching the given pattern from the '
#       'document at the current point indicated by the cursor . if failed to do '
#       'so , the method will be expected to throw an exception or take corre '
#       'ctive measures .'],
#  97: ['test for bug [ 97 40 36 ] bug in 0 . rc 1 databasemetadata method '
#       'gettable types ( )'],
#  98: ['this method will be used to check whether stream is already present in '
#       'cache or not for filepath if not present then create it and then add to '
#       'cache , other wise get from cache'],
#  99: ['removes a listener from the set of listeners'],
#  100: ['returns what the serialization specification calls " descriptor " '
#        'given a field signature .'],
#  101: ['adds an array of parameters to be used in the post request body . logs '
#        'a warning if the parameters argument is null .'],
#  102: ['creates an annotation name from a class name . for example l foo . bar '
#        '; becomes l foo . bar $ $ ; nb in sun vms the annotation name of the '
#        'first annotation is $ proxy 1 . classpath may later rely on this to '
#        'implement serialization correctly .'],
#  103: ['checks whether a given resource id supports advanced reservations or '
#        'not .'],
#  104: ['a service wrapper for the create electron ict ext method method . '
#        'forces permissions to be checked .'],
#  105: ['ctor - for use to create a pattern expression tree , without pattern '
#        'child expression .'],
#  106: ['compute the intersection of two line segments .'],
#  107: ['method which removes the specified object class from original set and '
#        'returns the set of object classes that were removed .'],
#  108: ['get the seconds since 1970 - 01 - 01 00 : 00 : 00 utc . see http : / / '
#        'dev . mysql . com / doc / ref man / 5 . 1 / en / date - and - time - '
#        'functions . html function unix - timestamp'],
#  109: ['is there a pdf license'],
#  110: ['draws the grid background'],
#  111: ['opens a stream to an entry in the jar .'],
#  112: ['unpacks the compressed character translation table .'],
#  113: ['process the result of copy and upload content ur ist ask'],
#  114: ['create the omgraphics using the shape file and spatial index .'],
#  115: ['returns common pool queue for a thread that has submitted at least one '
#        'task .'],
#  116: ['checks if the given field has package - private visibility'],
#  117: ['divide : rounding mode is round half up , result is positive ; '
#        'distance = - 1'],
#  118: ['helper method . does all the real work for restore ms word list format '
#        'for user ( ) .'],
#  119: ['this method will be invoked when the current page is scrolled , either '
#        'as part of a programmatically initiated smooth scroll or a user '
#        'initiated touch scroll . if you override this method you must call '
#        'through to the superclass implementation ( e . g . super . onpage '
#        'scrolled ( position , offset , offset pixels ) ) before onpage '
#        'scrolled returns .'],
#  120: ['converts all color and format codes'],
#  121: ['loads the database from the given input stream .'],
#  122: ['calculate selector radius the selector radius can be calculated by a '
#        'simple math calculation of the larger side .'],
#  123: ['determines the width of this view'],
#  124: ['test bulk get / put byte [ ] methods .'],
#  125: ['an object was added .'],
#  126: ['parser for the local phone .'],
#  127: ['transforms multiple paths will all matrices .'],
#  128: ['decodes a byte array from base 64 format . no blanks or line breaks '
#        'are allowed within the base 64 encoded input data .'],
#  129: ['ensures the truth of an expression involving the state of the calling '
#        'instance .'],
#  130: ['item will slide from top of the screen to its natural position .'],
#  131: ['construct a new mutable biginteger with a magnitude equal to the '
#        'specified mutable biginteger .'],
#  132: ['handle request sent with a wrong binding'],
#  133: ['loads the checkpoints from the given stream'],
#  134: ['load from the store .'],
#  135: ['provides a string representation of whether this connection is closed '
#        'or not'],
#  136: ['puts the given parameter value into a new list object then adds it to '
#        'the map .'],
#  137: ['returns the minimum dimensions needed to lay out the components '
#        'contained in the specified target container .'],
#  138: ['a coordinate descent algorithm for l1 - loss and l2 - loss epsilon - '
#        'sv r dual problem min \\ beta 0 . 5 \\ beta ^ t ( q + diag ( lambda ) '
#        ') \\ beta - p \\ sum i = 1 ^ l | \\ beta i | + \\ sum i = 1 ^ l yi \\ '
#        'beta i , s . t . - upper bound i < = \\ beta i < = upper bound i , '
#        'where q ij = xi ^ t xj and d is a diagonal matrix in l1 - svm case : '
#        'upper bound i = c lambda i = 0 in l2 - svm case : upper bound i = inf '
#        'lambda i = 1 / ( 2 c ) given : x , y , p , c eps is the stopping '
#        'tolerance solution will be put in w see algorithm 4 of ho and lin , '
#        '2012'],
#  139: ['select a view from position in the adapter'],
#  140: ['returns an enumeration describing the available options .'],
#  141: ['ignorable whitespace . for this method to be called , the document '
#        'source must have some way of determining that the text containing only '
#        'whitespace characters should be considered ignorable . for example , '
#        'the validator can determine if a length of whitespace characters in '
#        'the document are ignorable based on the element content model .'],
#  142: ['get editor for provided file , returns once editor is active or after '
#        'timeout'],
#  143: ['returns the solution with the largest objective value for the given '
#        'objective .'],
#  144: ['returns the y position based on latitude . note that this is based of '
#        'mercator which will have infinite number of points appro aching + / - '
#        '90 degrees . so if we are out of range , ( beyond the configured min / '
#        'max latitude ) , we return - 1 and max ap units based on which '
#        'direction we are out'],
#  145: ['registration for event change notifications . only sms notification '
#        'manager would be calling this method to register itself'],
#  146: ['parses an ascii property list from an input stream .'],
#  147: ['function to be minimized : - log likelihood . it is assumed that '
#        'compute fi buffer and comput ecur rent pi were called before this '
#        'method .'],
#  148: ['creates a new instance of gram mat ical ity estimator , using a given '
#        'set of documents for training .'],
#  149: ['change this should review zone . java'],
#  150: ['verifies that next poisson ( mean ) generates an empirical '
#        'distribution of values consistent with poiss on distribution impl by '
#        'generating 1000 values , computing a grouped frequency distribution of '
#        'the observed values and comparing this distribution to the '
#        'corresponding expected distribution computed using poiss on '
#        'distribution impl . uses chis qu are test of goodness of fit to '
#        'evaluate the null hypothesis that the distributions are the same . if '
#        'the null hypothesis can be rejected with confidence 1 - alpha , the '
#        'check fails .'],
#  151: ['loop and ensure all elements are non - in fi ite and non - nan , '
#        'throws an exception if one is'],
#  152: ['measure and layout all currently visible children .'],
#  153: ['processes game events occurring on this connection by dispatching them '
#        'to any registered game listener objects .'],
#  154: ['gets the percent of values within the specified value range .'],
#  155: ['closes resource without reporting any error .'],
#  156: ['similar to the release pagecontext method , but take lucee pagecontext '
#        'as entry'],
#  157: ['adds a new event listener to this dialog .'],
#  158: ['we only rebuild the journal when it will hal ve the size of the '
#        'journal and eliminate at least 2000 ops .'],
#  159: ['returns this java string as a null - terminated byte array'],
#  160: ['atomically load the properties file at the given location within the '
#        'designated class loader .'],
#  161: ['returns true if the object is a graph with the same content .'],
#  162: ['parses a name - value - pair with the given parser .'],
#  163: ['actions a pull event'],
#  164: ['returns the mapping object at the location in map indicated by loc .'],
#  165: ['parse the file to string with the json'],
#  166: ['find the differences between two texts . simplifies the problem by '
#        'stripping any common prefix or suffix off the texts before diff ing .'],
#  167: ['construct a new repository with the given default domain .'],
#  168: ['returns the number of unprocessed tokens remaining in the string .'],
#  169: ['possibly better in ul tra low memory environments ? reuses the above '
#        'method by creating a queue with one element and passes it in .'],
#  170: ['reset all common components before parsing'],
#  171: ['updates the label field of the invalid tgt , and if the volume is fron '
#        'ted by a vplex volume , also updates the target vplex volume label .'],
#  172: ['shows the given errors to the user .'],
#  173: ['handle serialization a little bit better , replacing the i18 n and '
#        'beancontext child support .'],
#  174: ['paint the arrow in enabled state .'],
#  175: ['logs a thrown exception .'],
#  176: ['convert a small bigdecimal to biginteger'],
#  177: ['called when the accuracy of the sensor has changed .'],
#  178: ['indicates whether this sub - command will allow unnamed trailing '
#        'arguments . these will be arguments at the end of the list that are '
#        'not preceded by either a long or short identifier and will need to be '
#        'manually parsed by the application using this parser . note that once '
#        'an unnamed trailing argument has been identified , all remaining '
#        'arguments will be classified as such .'],
#  179: ['setmax crl number ( biginteger max crl ) method testing . tests if '
#        'crls with any crl number value match the selector in the case of null '
#        'crl number criteria , if specified max crl value matches the selector '
#        ', and if crl with inappropriate crl number value does not match the '
#        'selector .'],
#  180: ['checks if the given mouse event is a popup trigger and creates a new '
#        'popup menu if necessary .'],
#  181: ['remove a task if it has index > = min . if it is active and not being '
#        'executed by the calling thread , interrupt the thread executing the '
#        'task .'],
#  182: ['java . math . bigdecimal divide ( java . math . bigdecimal , java . '
#        'math . roundingmode ) divide ( bigdecimal , roundingmode )'],
#  183: ['ensures that the given path exists with no data , the current acl and '
#        'no flags'],
#  184: ['override loadclass so we can check package access .'],
#  185: ['determines the height of this view'],
#  186: ['this only checks clipping along the bottom edge .'],
#  187: ['creates a new scheduling rule factory for the given workspace'],
#  188: ['writes a byte array to a file creating the file if it does not exist '
#        '.'],
#  189: ['adds the specified item to the end of the list'],
#  190: ['checks and flushes custom event messages if no nodes are attempting to '
#        'join the grid .'],
#  191: ['determines the number of consecutive characters that are encodable '
#        'using numeric compaction .'],
#  192: ['parses the current node and returns the number of elements added .'],
#  193: ['calculates sc ram ble image height multiplier to respect aspect ratio'],
#  194: ['unit test to verify that limited number of core types do not include '
#        'type information , even if declared as object . this is only done for '
#        'types that json scalar values natively map to : string , integer and '
#        'boolean ( and nulls never have type information )'],
#  195: ['the listener is not closed until after the after region destroy event'],
#  196: ['static version of indexof , to allow repeated calls without needing to '
#        're - acquire array each time .'],
#  197: ['populate the profiles combobox and select the default .'],
#  198: ['read the file header and return the log sequence number stored in the '
#        'file header .'],
#  199: ['absolute value of real component'],
#  200: ['returns the type of the extre mum at the specified alpha values .'],
#  201: ['returns oid for alg name'],
#  202: ['provide reflective behavior to construct instance of generator given '
#        'an array of string arguments .'],
#  203: ['refills the input buffer .'],
#  204: ['when there is an inplace editor we " listen " all mouse event and '
#        'finish editing by any mouse pressed or mouse released event . we are '
#        'acting like yet another glass pane over the standard glass layer .'],
#  205: ['add a module to the set of modules to load and register its services'],
#  206: ['makes sure that all required bin navi database tables exist . this '
#        'method tries to find out whether the database is empty or already '
#        'initialized ( or inconsistent ) .'],
#  207: ['this method classifies several instances at once'],
#  208: ['bind header with provided viewholder at specified position'],
#  209: ['updates the displayed list of lines .'],
#  210: ['draws a rectangle of given half width and half height , centered on ( '
#        'x , y ) .'],
#  211: ['re - measure the loading views height , and adjust internal padding as '
#        'necessary'],
#  212: ['replaces a split element with another one'],
#  213: ['called to start an item list .'],
#  214: ['pick a number of initial splits based on the number of records '
#        'expected to be processed .'],
#  215: ['invoked when the mouse has been clicked on a component .'],
#  216: ['scans a single source dir for sources and includes only the files '
#        'whose name match the patterns in source includes and excludes all '
#        'files whose names match the patterns in source excludes'],
#  217: ['returns true if there is another postpon ed route to try .'],
#  218: ['check if the selection has a single element'],
#  219: ['constructs a path from an uri'],
#  220: ['reads a xml element attribute ans cast it to a int value'],
#  221: ["returns the remainder of ' reader ' as a string , closing it when done "
#        '.'],
#  222: ['adds the getters for a property that is identified by a property '
#        'number which indexes into array of getters per type .'],
#  223: ['marks the specified entry as used by setting its last used time to the '
#        'current time in nanoseconds .'],
#  224: ['default : just returns " success "'],
#  225: ['handle node leaving the ring . this will happen when a node is '
#        'decommissioned'],
#  226: ['registers implementing class of the transform algorithm with algorithm '
#        'uri'],
#  227: ['constructs ignite cache key / value persistence settings .'],
#  228: ['returns true if the input string contains a word - breaking character '
#        '.'],
#  229: ['checks all pairs of segments for intersections at an interior point of '
#        'a segment'],
#  230: ['removes the first occurrence , starting at the beginning and moving '
#        'towards the end , of the specified object from this vector . all '
#        'elements with an index bigger than the element that gets removed have '
#        'their index decreased by 1 .'],
#  231: ['compose two functions together into a single function'],
#  232: ['add cdc column specifications .'],
#  233: ['utility method to convert a variable name into java field name .'],
#  234: ['a function that generates random aes & hmac keys and prints out '
#        "exceptions but doesn ' t throw them since none should be encountered . "
#        'if they are encountered , the return value is null .'],
#  235: ['ensures the truth of an expression involving one or more parameters to '
#        'the calling method .'],
#  236: ['use the parameter sqlite database to execute the passing sq ls . '
#        'subclasses can add their own logic when do the executing job by '
#        'overriding this method .'],
#  237: ['creates a new journal that omits redundant information . this replaces '
#        'the current journal if it exists .'],
#  238: ['refreshes the done button . the label will say the opposite of the '
#        'player \' s " done " status , indicating that clicking it will reverse '
#        'the condition .'],
#  239: ['create the basic editor .'],
#  240: ['this method will be invoked when the current page is scrolled , either '
#        'as part of a programmatically initiated smooth scroll or a user '
#        'initiated touch scroll . if you override this method you must call '
#        'through to the superclass implementation ( e . g . super . onpage '
#        'scrolled ( position , offset , offset pixels ) ) before onpage '
#        'scrolled returns .'],
#  241: ['used to communicate a progress update between a plugin tool and the '
#        'main whitebox user interface .'],
#  242: ['ensures there is enough space in the buffer for the given number of '
#        'additional bytes .'],
#  243: ['accepts an ipv 4 address of the form xxx . xxx . xxx . xxx , ie 192 . '
#        '168 . 0 . 1 and returns the corresponding 32 bit integer .'],
#  244: ['close the given cursor and remove it from the map'],
#  245: ['determines if the remaining g ser string matches the provided pattern '
#        '.'],
#  246: ['push i onto our operand stack'],
#  247: ['create an xml node with optional attributes and content . the data is '
#        'indented with 4 spaces if it contains a newline character and the '
#        'indent parameter is set to true .'],
#  248: ['adds the specified item to the list with the specified position'],
#  249: ['notify unsuccessful completion of the operation'],
#  250: ['transform an xsl - fo streamsource to the specified output format .'],
#  251: ['splits the input string based on the default delimiter , and also '
#        'escapes delimiter .'],
#  252: ['reads data with blocking . should be used in case when ready method '
#        'always returns false for your input stream . should be used if we want '
#        'to to make our reader exit when end of stream reached . could be used '
#        'if we prefer io - blocking over cpu sleeping .'],
#  253: ['remove an obligation from every state in the state set .'],
#  254: ['set bounds for the right textview including clip padding .'],
#  255: ['creates a nes compound content for the given blob information .'],
#  256: ['checks , whether all attributes are covered by cluster definitions and '
#        'returns true in that case .'],
#  257: ['search for a string in the enumeration .'],
#  258: ['returns the first index of elt in the array if < len , else - 1 .'],
#  259: ['add a new value for name'],
#  260: ['compares the argument to this certificate . if both have the same '
#        'bytes they are assumed to be equal .'],
#  261: ['appending the between operator clause .'],
#  262: ['encode a unicode string .'],
#  263: ['used to communicate a progress update between a plugin tool and the '
#        'main whitebox user interface .'],
#  264: ['build an occurrence count by value for the given time serie .'],
#  265: ['this function will take a song entry and update it to the latest week '
#        'and increase the count for the current week by 1 if necessary'],
#  266: ['recursively assign node weights .'],
#  267: ['creates a new instance of search engine'],
#  268: ['adds a field to run the query string against .'],
#  269: ['combines multiple stages by applying a function .'],
#  270: ['return a statement that will create the schema , null if no create '
#        'schema can be given'],
#  271: ['and for a negative and a positive numbers ; the first is shorter'],
#  272: ['create a new manager object .'],
#  273: ['returns the list of sentences in the knowledge base chained together '
#        'as a single sentence .'],
#  274: ['determine if the expression is a pro noun .'],
#  275: ['output the sql type for a java short .'],
#  276: ['breaks a string to multiple strings ( similar to string tokenizer )'],
#  277: ['write all modified favorites to the data stream .'],
#  278: ['update the fps counter . call this method every frame !'],
#  279: ['validates all fields based on their value and their validation rules '
#        'if a field is pre filled from the account on file , but it has been '
#        'altered , it will be validated .'],
#  280: ['create an empty state .'],
#  281: ['note , does not make a defensive copy of any of the data .'],
#  282: ['handle a change in the slider by updating the dataset value . this '
#        'automatically triggers a chart repaint .'],
#  283: ['parse a list of substrings separated by a given delimiter . the '
#        'delimiter can also appear in substrings ( just double them ) : parse '
#        'delimited string ( " this | is " , \' | \' ) returns [ " this " , " is '
#        '" ] parse delimited string ( " this | | is " , \' | \' ) returns [ " '
#        'this | is " ]'],
#  284: ['lays out the panel'],
#  285: ['returns true if the gui is started and not paused , and false '
#        'otherwise .'],
#  286: ['creates a default mosaic definition .'],
#  287: ['creates a result based on a single relational expression .'],
#  288: ['set the default x509 trust manager to an instance of a fake class that '
#        'trust all certificates , even the self - signed ones .'],
#  289: ['is the component in need of a form .'],
#  290: ['adds all internal listeners . currently this just consists of an item '
#        'listener for the combo - box which switches to the correct " card " '
#        'for the given probability distribution .'],
#  291: ['the " safe " square root of the input value , handling negative values '
#        'by simply making them positive and then neg ating the return value .'],
#  292: ['runs callable tasks each in separate threads .'],
#  293: ["appends a character to parser ' s buffer ."],
#  294: ['sets the provided state manager as the owner for the provided field '
#        'value .'],
#  295: ['construct a select statement suitable for use in a group of select '
#        'statements that will be joined through union operators in build union '
#        'query .'],
#  296: ['constructs a node with the given location .'],
#  297: ['adds an element to the counter or caches it to be added .'],
#  298: ['reverts the list of files we are passed .'],
#  299: ['concatenates a list of float arrays into a single array .'],
#  300: ['iterator over all values following an occurrence of tag in al ine . '
#        'example : al ine = gi | 44 44 | gi | 55 55 and tag = gi | with return '
#        '44 44 and then 55 55 value consists of letters , digits or underscore'],
#  301: ['move higher in the tree , beyond even an apparent root of tree .'],
#  302: ["returns true if there ' s an associated file ."],
#  303: ['writes the contents of the internal buffer to the given array starting '
#        'at the given offset . assumes the array has space to hold count bytes '
#        '.'],
#  304: ['dismisses item from the given position .'],
#  305: ['calculate a normal probability density function ( pdf ) based on a '
#        'variance and mean value'],
#  306: ['sorts an array of strings , returning a new array with the sorted '
#        'items . the original array is left untouched .'],
#  307: ['adds a new zoom listener .'],
#  308: ['initialize ( clear ) the d node field in register for all registers in '
#        'this basic block by setting them to null . handles both explicit and '
#        'implic t use / defs .'],
#  309: ['fire when an annotation has been selected .'],
#  310: ['updates the prediction stats and return whether prediction is allowed '
#        '. the policy is : 1 . if the client does not wait more than m delay ms '
#        ', decline the request . 2 . if the client waits for more than m delay '
#        'ms but less than 2 m delay ms , accept the request and double m delay '
#        'ms . 3 . if the client waits for more than 2 m delay ms , accept the '
#        'request and reset m delay ms . and : 100 ms < = m delay ms < = 10 s . '
#        'this way , if an application sends a burst of requests , it is quickly '
#        'ser iously throttled . if it stops being this way , back to normal .'],
#  311: ['authenticates the server evidence message m2 received and saves it '
#        'only if correct .'],
#  312: ['handles any pure text ( containing no control characters ) in the '
#        'input stream . called by the superclass .'],
#  313: ['remove a service from the registry and / or set of known aliases .'],
#  314: ["removes each two leading ' \\ ' , removes leading $ , removes examples "
#        ': $ q qq - > q qq \\ $ q qq - > q qq if dummy attributes are collected '
#        'too , null otherwise \\ \\ $ q qq - > q qq $ q qq - > q qq'],
#  315: ['constructs an escap ed writer around the given writer .'],
#  316: ['returns true if this cookie has expired .'],
#  317: ['records the record builder impl , and verifies if required'],
#  318: ['compare the method that was called to the intended method when the os '
#        'x adapter instance was created ( e . g . handle about , handle quit , '
#        'handle open file , etc . ) .'],
#  319: ['remainder of division of two positive numbers'],
#  320: ['resets the state of this builder .'],
#  321: ['\\ brief distance ( vec 3 a , vec 3 b )'],
#  322: ['checks version and ips'],
#  323: ['convert to lower case , and check that all chars are ascii '
#        "alphanumeric , ' - ' or ' . ' only ."],
#  324: ['create a negative number from a sign and an array of bytes . the '
#        'number fits in an integer .'],
#  325: ['builds and returns a opus comment .'],
#  326: ['assert that the property values of a new event and a removed event '
#        'match the expected insert and removed values .'],
#  327: ['returns the number of elements in this set .'],
#  328: ['safely convert the string to uppercase .'],
#  329: ["iterator over the knowledge edge ' s representing required edges ."],
#  330: ['unlocks the objects acquired from locking . this method should always '
#        'be in a finally block immediately after the lock . if you try to '
#        'unlock from another thread , no objects are unlocked .'],
#  331: ['creates and returns a string formatted so it will fit in a box '
#        'suitable for a java doc header .'],
#  332: ['for c enumber stringto two digits , this takes a string of digits , '
#        'and forces it to be two digits long . first any extra leftmost digits '
#        'are truncated , leaving only the right one digit or right two digits . '
#        'if there is only one digit , it is zero padded to enforce a two digit '
#        'string result . this function is used by the date picker utilities . '
#        'do e spar sed date match text ( ) function .'],
#  333: ['adds a named item to the list of items that will be dropped on dead if '
#        "clear drop itemlist hasn ' t been called first , this will change all "
#        'creatures of this kind .'],
#  334: ['finds jpa entities by their primary keys .'],
#  335: ['load work fl w and initialize the session attributes .'],
#  336: ['returns a hashcode value for this certificate from its encoded form .'],
#  337: ['removes the from tags .'],
#  338: ['verifies the given sec p 256 k 1 signature in native code . calling '
#        'when enabled = = false is undefined ( probably library not loaded )'],
#  339: ['recursively delete the webapp directory .'],
#  340: ['verifies that the iterator visits the specified objects in some '
#        'arbitrary ordering and that the iterator is exhausted once all '
#        'expected objects have been visited . the implementation uses a '
#        'selection without replacement " pattern " .'],
#  341: ['formats the finished percentage of a rollout group into a string with '
#        'one digit after comma .'],
#  342: ['generates the hostname for a node .'],
#  343: ['transfer all the sequences listed in the supplied file , interpreting '
#        'entries appropriately .'],
#  344: ['helper method for over scrolling that encapsulates all of the '
#        'necessary function . this is the advanced version of the call .'],
#  345: ['removes the outermost property from a nested getter expression'],
#  346: ['if we have all pi echart config then there is no point in reloading '
#        'it'],
#  347: ['generates a ( random ) time difference between two events'],
#  348: ['creates the line structure for the given text . newly created lines '
#        'are inserted into the line structure starting at the given position . '
#        'returns the number of newly created lines .'],
#  349: ['returns the positive square root of the specified value .'],
#  350: ['counts the number of black / white transitions between two points , '
#        "using something like b res enh am ' s algorithm ."],
#  351: ['convert a number into a bit string with separators between each group '
#        'of 8 .'],
#  352: ['encodes an array of bytes into an array of url safe 7 - bit characters '
#        '. unsafe characters are escaped .'],
#  353: ['initializes with the string contents .'],
#  354: ['waits for all threads to reach this barrier .'],
#  355: ['populates the translation scache map unless it is already populated .'],
#  356: ['construct a nav mouse mode . lets you set the consume mode . if the '
#        'events are consumed , then a mouseevent is sent only to the first map '
#        'mouselistener that successfully processes the event . if they are not '
#        'consumed , then all of the listeners get a chance to act on the event '
#        '.'],
#  357: ['adds a new event to the queue . adding a new event to the queue '
#        'preserves the temporal order of the events in the queue .'],
#  358: ['stops the timer with the specified name .'],
#  359: ['returns the summary as string .'],
#  360: ['create a hierarchy of directories ( a path ) in the designated temp '
#        'dir . if the jvm terminates normally , these will be cleaned up .'],
#  361: ['draws a horizontal span into the graph and optionally adds a legend .'],
#  362: ['select also all items belonging to any connection of the current '
#        'selected items .'],
#  363: ['create a new instance that optionally supports unicode sort keys .'],
#  364: ['removes from the list of nodes any that cannot be parents of x given '
#        'the background knowledge .'],
#  365: ['called with an input stream for a properties file , used for reading '
#        'tiles . o mp files .'],
#  366: ['open a new database connection . this connection must be closed by '
#        'calling conn . close ( ) .'],
#  367: ['a simple implementation of the add relations method which presents the '
#        'general concept of the method . it should not be used in production '
#        'because of possible race condition - production ready code should '
#        'perform an atomic operation .'],
#  368: ['the b dd p packets are forwarded out of all the ports out of an open '
#        'flow domain . get all the switches in the same openflow domain as the '
#        'sw ( disabling tunnels ) . then get all the external switch ports and '
#        'send these packets out .'],
#  369: ['waits the specified number of milliseconds .'],
#  370: ['verify that the write set is not found ( no keys in [ 0 : 1000 ) ) .'],
#  371: ['calculates the entropy corresponding to the input masses .'],
#  372: ['check to see if a string is a valid nmtoken according to [ 7 ] in the '
#        'xml 1 . 0 recommendation'],
#  373: ['determines what action the user wants to perform .'],
#  374: ['parses out and converts the text located between first occurrences of '
#        'the open and closed tags into double .'],
#  375: ['place a string into the message ( using utf - 8 encoding )'],
#  376: ['actions a pull event'],
#  377: ['add a rtcp event listener'],
#  378: ['creates a new array of the given size if necessary and copies the data '
#        'into the new array .'],
#  379: ['this method detects a code in a " pure " image - - that is , pure mono '
#        'chrome image which contains only an un rotated , un skewed , image of '
#        'a code , with some white border around it . this is a specialized '
#        'method that works exceptionally fast in this special case .'],
#  380: ['reports an error . errors are non - fatal and usually signify that the '
#        'document is invalid with respect to its grammar ( s ) .'],
#  381: ["connects socket ' fd ' to ' inetaddress ' on ' port ' , with no "
#        "timeout . the lack of a timeout means this method won ' t throw socket "
#        'timeoutexception .'],
#  382: ['determine if the string - value of a node is whitespace'],
#  383: ['creates a new status panel .'],
#  384: ['open the p ds file .'],
#  385: ["deregisters a spring from this base spring system , so it won ' t be "
#        'iterated anymore . the spring should not be used anymore after doing '
#        'this .'],
#  386: ['returns current log file .'],
#  387: ['parses an n - triples bnode , creates an object for it using the '
#        'supplied value factory and returns this object .'],
#  388: ['resets the ps r list .'],
#  389: ['sorts the specified array in ascending numerical order .'],
#  390: ['close this popup menu .'],
#  391: ['remove an object from the map .'],
#  392: ['expand the view vertically to the size of the cross size ( considering '
#        'the view margins )'],
#  393: ['convert a 32 char hex string into a inet 6 address . throws a runtime '
#        "exception if the string isn ' t 32 chars , isn ' t hex or can ' t be "
#        'made into an inet 6 address'],
#  394: ['track a failure - multiply the back off interval by the multiplier'],
#  395: ['reads a double ( 64 bit ) from the source stream .'],
#  396: ['check if a scroll bar is at its maximum value .'],
#  397: ['case sensitive match test .'],
#  398: ['given a url to a properties file describing a map tileset , create it '
#        'and add it to the list .'],
#  399: ['computes the result for one input double value .'],
#  400: ['enables pan te th ering on the local device and checks to make sure '
#        'that te th ering is enabled .'],
#  401: ['calculate the number of cells on the shortest path between ( x1 , z1 ) '
#        'and ( x2 , z2 )'],
#  402: ['creates a new url of the given component parts . the url uses the '
#        "protocol ' s default port ."],
#  403: ['return a workflow . method for creat evol umes .'],
#  404: ['example : 0x 1001 , " close " , 0x0 , " "'],
#  405: ['initializes the widgets in this page'],
#  406: ['this function will install a trust manager that will blindly trust all '
#        'ssl certificates . the reason this code is being added is to enable '
#        'developers to do development using self signed ssl certificates on '
#        'their web server . the standard http sur lconnection class will throw '
#        'an exception on self signed certificates if this code is not run .'],
#  407: ['sample the active count'],
#  408: ['handles get requests to the oauth 2 device / user endpoint , returning '
#        'a form to allow the user to submit their user code'],
#  409: ['test for correct reading of a mission name .'],
#  410: ['checks if this object equals another . the entire state of the object '
#        'is compared .'],
#  411: ['releases any resources we may have ( or inherit )'],
#  412: ['computes the black equivalent volatility without validating '
#        'parameters'],
#  413: ['closes the utility instance and unregisters any broadcastre ceiv ers '
#        '.'],
#  414: ['resolves all files it finds into a map , with relative paths as the '
#        'key and absolute path as the value .'],
#  415: ['javax / crypto / exemp tion mechanism getinstance ( string algorithm , '
#        'string provider ) checks exception order'],
#  416: ['reload configuration from previously added resources . this method '
#        'will clear all the configuration read from the added resources , and '
#        'final parameters . this will make the resources to be read again '
#        'before accessing the values . values that are added via set methods '
#        'will overlay values read from the resources .'],
#  417: ['removes a message processor from this sip stack .'],
#  418: ['construct an x509 issuer serial from an x509 certificate .'],
#  419: ['add the set to an existing file .'],
#  420: ['put an array of bytes in the buffer .'],
#  421: ['convenience method to return a string array as a delimited ( e . g . '
#        'csv ) string . e . g . useful for tostring ( ) implementations .'],
#  422: ['removes all items from the stag ing area .'],
#  423: ['parse attributes and return ade mp ie re color'],
#  424: ['method that creates a new instance of lu a state'],
#  425: ['checks memory for capacity to hold the preamble and returns the first '
#        '8 bytes .'],
#  426: ['read from the file .'],
#  427: ['if the normalized scale is equal to 1 , then the image is made to fit '
#        'the screen . otherwise , it is made to fit the screen according to the '
#        'dimensions of the previous image matrix . this allows the image to '
#        'maintain its zoom after rotation .'],
# ...
#  8544: ['appends message if the given name is similar to the candidate .'],
#  8545: ['this is called by superclass when attempt to write data from file .'],
#  8546: ['returns the vendor for the java version used to generate this build '
#         '.'],
#  8547: ['creates an instance of a voice result .'],
#  8548: ['forms tree of the nodes linked from this node .'],
#  8549: ['this recursive method is a hack : directory items flattens the '
#         'directory structure , but it provides useful functionality , so this '
#         'method will reconstruct the directory structure for the jtree .'],
#  8550: ['adds the specified listener to the list of listeners that will be '
#         'notified of drawer events .'],
#  8551: ['method used to enter note edition mode'],
#  8552: ['adds an entry to the source map ( entry must be added in order ) .'],
#  8553: ['onclick handler - un hide action bar'],
#  8554: ['formats a time delta in human readable format .'],
#  8555: ['the main execution loop which should be executed in its own thread .'],
#  8556: ['used to check whether there is a specialized handler for a given '
#         'intent .'],
#  8557: ['set bounds for the right textview including clip padding .'],
#  8558: ['takes a probability distribution and reduces higher - order terms by '
#         'contributions arising from combinations of lower order terms . it '
#         'assumes the input distribution is suitable for this operation .'],
#  8559: ['remove / collapse multiple newline characters'],
#  8560: ['readobject is called to restore the state of the exe cop tion '
#         'permission from a stream .'],
#  8561: ['returns the total of the values in one column of the supplied data '
#         'table by taking only the row numbers in the array into account .'],
#  8562: ['opens the analysis . also clears the source and summary panes . makes '
#         'comments enabled false . sets the save type and adds the file to the '
#         'recent menu .'],
#  8563: ['method for beancontext membership interface .'],
#  8564: ['performs some processing on the given item .'],
#  8565: ['removes instances from containers during scaling down'],
#  8566: ['draws a message which is sent between two different lif elines'],
#  8567: ['kills consist using lead loc o address'],
#  8568: ['listen on the default address'],
#  8569: ['parses a sum of flags as numerical values ( bitmask ) and translates '
#         'it to set of enum values .'],
#  8570: ['defines a new package using the information extracted from the '
#         'specified manifest .'],
#  8571: ['parse the xml document content using specified handlers and an input '
#         'source .'],
#  8572: ['verifies the signature bytes .'],
#  8573: ['add string to see if it matches in the query'],
#  8574: ['closes the cache and deletes all of its stored values . this will '
#         "delete all files in the cache directory including files that weren ' "
#         't created by the cache .'],
#  8575: ['get time ago that milliseconds date occurred'],
#  8576: ['converts a string with an even number of hexadecimal characters to a '
#         'byte array .'],
#  8577: ["called when we want to remove a jobstatus object that we ' ve "
#         'finished executing . returns the object removed .'],
#  8578: ['returns the coefficient of variance .'],
#  8579: ['transfers node , if necessary , to sync queue after a cancelled wait '
#         '. returns true if thread was cancelled before being signalled .'],
#  8580: ['prints out a representation of the term .'],
#  8581: ['creates an instance , loads requirements file .'],
#  8582: ['this is called when the service is added for the first time and it '
#         'will change the default install value of an attribute .'],
#  8583: ['convert a canonical java class name to dal vi k flavor .'],
#  8584: ['emit a method that ensures a collection is initialized .'],
#  8585: ['unregisters a client to be monitored .'],
#  8586: ['this method handles double quotes .'],
#  8587: ['allocate a new container of a given capacity'],
#  8588: ['check if uri represents local resource'],
#  8589: ['check if min e sh after is present . if it is , we need to bypass it '
#         'to send post requests'],
#  8590: ['helper to synchronously wait until we can get a path for a given obb '
#         'file'],
#  8591: ['block consistency group is not a zone level resource'],
#  8592: ['protocol safety checks for the server returned message .'],
#  8593: ['closes target and source databases'],
#  8594: ['cal cola il md 5 del mess agg io , us ando la crypto api .'],
#  8595: ['runs the job to scan the metastore for directory locations .'],
#  8596: ['helper method for over scrolling that encapsulates all of the '
#         'necessary function . this is the advanced version of the call .'],
#  8597: ['deletes sub people containers in this people container .'],
#  8598: ['test of fin dre cent message uid sin mailbox method , of class hbase '
#         'message mapper .'],
#  8599: ['queue an " event " to be run on the gl rendering thread .'],
#  8600: ['return list of error messages found while parsing last template .'],
#  8601: ['ensure that the buffer has at least capacity to hold the target size'],
#  8602: ['performs the best effort of updating zk node basepath / key to the '
#         'provided value . the semantics provided are as follows : the value is '
#         'written regardless of the current value associated with the key . if '
#         "the key doesn ' t exist and we lose the race to create the key , we "
#         'will throw an exception .'],
#  8603: ['timing target implementation : calculate and set the current car '
#         'position based on the animation fraction'],
#  8604: ['process the source tree to the output result .'],
#  8605: ['processes a " query " using a user constructed solr queryrequest , '
#         'and closes the request at the end .'],
#  8606: ['compare link attributes . return whether they are the same or not .'],
#  8607: ['generate a unique id - that is friendly for a url or file system'],
#  8608: ['removes the provider at the specified 1 - based position .'],
#  8609: ['parses a ( non - top ) xml element .'],
#  8610: ['instances should not be constructed in standard programming .'],
#  8611: ['formats a given monetary value in a default format ( 2 decimals , '
#         'padded left to 10 characters ) .'],
#  8612: ['delete an instance of the entry class , and remove the class from '
#         'entry classes if this is the last such instance .'],
#  8613: ['loads the settings and stores them in a properties map .'],
#  8614: ['logs a warning message using the logger of this interpreter .'],
#  8615: ['reads an input stream into a single string result .'],
#  8616: ['construct a vector with preset values .'],
#  8617: ['remove a transaction service listener .'],
#  8618: ['used to communicate a progress update between a plugin tool and the '
#         'main whitebox user interface .'],
#  8619: ['pushes a new type onto the output frame stack .'],
#  8620: ['this methods sorts the vertices in level [ ] according to their bary '
#         "centers in bc [ ] , using insertion sort . it , however , doesn ' t "
#         'touch the vertices with bary center equal to zero .'],
#  8621: ['tests whether model classes can identified correctly as consistent .'],
#  8622: ['look at the object received in a maphandler status message and '
#         'connect to it if necessary .'],
#  8623: ['removes all layers from the map'],
#  8624: ['returns the number of productions contained in this rule .'],
#  8625: ['asynchronously create zookeeper path recursively and optim istically '
#         '.'],
#  8626: ['write this object to a stream .'],
#  8627: ['is net amount equal ?'],
#  8628: ['this method was generated by mybatis generator . this method '
#         'corresponds to the database table keyword'],
#  8629: ['creates an attribute which reads values from the field indicated '
#         'using reflection .'],
#  8630: ['processes a log event'],
#  8631: ['remove listener from the list to receive notification when a provi le '
#         'is added or removed .'],
#  8632: ['add an sms to the given uri with thread id specified .'],
#  8633: ['present the final image on the screen / viewport .'],
#  8634: ['increment a calendar by one day .'],
#  8635: ['push the given angular variable to the target interpreter angular '
#         'registry given a note id and a paragraph id'],
#  8636: ['removes from the given list the elements at the given indexes . '
#         'ignores indexes which are out of bounds of list .'],
#  8637: ['creates a new project tree component .'],
#  8638: ['determine if the expression is an object . ( a thing , not a person '
#         ')'],
#  8639: ['use interpolator to get t'],
#  8640: ['if enabled in the settings , requests / mods for one currently joined '
#         'channel ( and only one ) , ignoring the ones it was already requested '
#         'for .'],
#  8641: ['build depre ciation ( a depre ciation exp ) entries . more exactly , '
#         'is deleting not processed entries . and create new ones again . '
#         'warning : is not modifying work file ( this )'],
#  8642: ['iterates over all values and returns true if one value matches .'],
#  8643: ['updates the filename field to the new value .'],
#  8644: ['checks if another objects is available by attempting to read another '
#         'byte from the stream .'],
#  8645: ['non - zero exit status when any violation messages have severity . '
#         'error , controlled by - - max - severity'],
#  8646: ['remove the specified sensor from this sensor selection model .'],
#  8647: ['prints a way entity .'],
#  8648: ['returns a string representation of the data row .'],
#  8649: ['walks up the tree until a root object is found .'],
#  8650: ["returns true if there ' s another proxy to try ."],
#  8651: ['encapsulate logic for determining the case where no object ( neuron '
#         'node , syn p ase node , etc ) was clicked on at the beginning of this '
#         'drag sequence .'],
#  8652: ['this operation is not supported because sets are mutable .'],
#  8653: ['map measurement to a defined measurement name , where the key is the '
#         'measurement name and the value is the req ex the measurement should '
#         'be mapped by .'],
#  8654: ["given the location of the ' middle snake ' , split the diff in two "
#         'parts and recurse .'],
#  8655: ['validate credit card number . - check card type and length'],
#  8656: ['extract the contents of a zipfile to a directory .'],
#  8657: ['creates a new config within the config directory , using the filename '
#         'provided .'],
#  8658: ['creates new form goto line dialog'],
#  8659: ['attempts to prepare the request for a retry . if there are no more '
#         "attempts remaining in the request ' s retry policy , a timeout "
#         'exception is thrown .'],
#  8660: ['sets up the y - axis labels . computes the desired number of labels '
#         'between the two given extre mes . unlike the pap arex labels ( ) '
#         'method , this method needs to be called upon every refresh of the '
#         'view .'],
#  8661: ['for ges and sends the teardown request'],
#  8662: ['if this is the first time calling this method , the buffer will be '
#         'checked to make sure it starts with so i marker ( x ff d 8 ) . if the '
#         'image has been identified as a non - jpeg , data will be ignored and '
#         'false will be returned immediately on all subsequent calls . this '
#         'object maintains state of the position of the last read byte . on '
#         'repeated calls to this method , it will continue from where it left '
#         'off .'],
#  8663: ['test deploying a simple ear .'],
#  8664: ['gets the current filled and readable length of the array .'],
#  8665: ['equals method to be consistent with comparable'],
#  8666: ['send a notification via the m wifi monitor when the wifi state '
#         'changes .'],
#  8667: ['checks whether the value exists in an arraylist of certain key .'],
#  8668: ['removes the given listener from the list of diagram change listeners '
#         '.'],
#  8669: ['returns a connectivity grid object based on a hash value'],
#  8670: ['removes any leading $ from the given string .'],
#  8671: ['clears the " host context " system property'],
#  8672: ['creates a new p norm'],
#  8673: ['add separator routines are not used in peers . shared code invokes '
#         'additem ( " - " ) for adding separators'],
#  8674: ['adds a chart viewer to the stage and displays it .'],
#  8675: ['returns a buffer to the pool , throwing away old buffers if the pool '
#         'would exceed its allo tted size .'],
#  8676: ['accept a data point ( encapsulated in a chart event ) to plot'],
#  8677: ['assumptions : ranges are disjoint , non - contiguous , and ordered . '
#         'names of ranges are not necessarily preserved .'],
#  8678: ['support for get paren tof node ; walks a dom tree until it finds the '
#         'element which owns the attr . this is hu ge ly expensive , and if at '
#         'all possible you should use the dom level 2 attr . ow ne relement ( ) '
#         'method instead . the dom level 1 developers expected that fol ks '
#         "would keep track of the last element they ' d seen and could recover "
#         "the info from that source . obviously that doesn ' t work very well "
#         "if the only information you ' ve been presented with is the attr . "
#         'the dom level 2 geto w ne relement ( ) method fixes that , but only '
#         'for level 2 and later do ms .'],
#  8679: ['creates and starts a tail er for the given file .'],
#  8680: ['is operating system mac os ?'],
#  8681: ['returns the number of items in the collection .'],
#  8682: ['creates new d view asn 1 dump dialog where the parent is a dialog .'],
#  8683: ['remove all spaces on right .'],
#  8684: ['add a message in the buffer'],
#  8685: ['closes the current form and returns to the previous form , releasing '
#         'the edt in the process'],
#  8686: ['returns the signed distance of this line from p point . the result '
#         'will be positive , if the line is on the left of p point , else '
#         'negative .'],
#  8687: ['expands the given number string as a real number .'],
#  8688: ['ones - return a vector full of 1s .'],
#  8689: ['submits a requests for a set of permissions for an activity .'],
#  8690: ['tell the user of an error , and probably throw an exception .'],
#  8691: ['setting a null property is the way maven 2 operates when the user '
#         'specifies an empty property . we need to verify that the cargo plugin '
#         'intercepts that and replaces the null with an empty string .'],
#  8692: ['you are not supposed to instantiate this class .'],
#  8693: ['creates a new delete - xxx sub - command for a set relation .'],
#  8694: ['the following two methods remove cycles from the graph .'],
#  8695: ['returns a string representation of the given matrix .'],
#  8696: ["given a ' from ' pattern ( ala xsl : number ) , a match pattern and a "
#         'context , find the first ancestor that matches the pattern ( '
#         'including the context handed in ) .'],
#  8697: ["try to clean up as much as possible from a shell that ' s gotten "
#         'itself wed ged . hopefully the stream gob bl ers will cro ak on their '
#         'own when the other side of the pipe is closed .'],
#  8698: ['this is a facade method for the encoding operation . this method '
#         'encodes the remaining character sequence of the given character '
#         'buffer into a new byte buffer . this method performs a complete '
#         'encoding operation , resets at first , then encodes , and flushes at '
#         'last . this method should not be invoked if another encode operation '
#         'is ongoing .'],
#  8699: ['creates a metrics object with the dimensions map immutable'],
#  8700: ['resol vec lass is extended to acquire ( if present ) the location '
#         'from which to load the specified class . it will find , load , and '
#         'return the class .'],
#  8701: ['instances should not be constructed in standard programming .'],
#  8702: ['checks whether a re spawn point is within this area .'],
#  8703: ['inserts a byte array']}

# %%
import pickle
hyp = pickle.load(open('hyp.pkl', 'rb'))
pprint(hyp)
# Out:
# {0: ['returns a 0 - based depth within the object graph of the current object '
#      'being serialized .'],
#  1: ['checks whether the scheme alters the training dataset during training . '
#      'if the scheme needs to modify the training data it should take a copy of '
#      'the training data . currently checks for changes to header structure , '
#      'number of instances , order of instances , instance weights .'],
#  2: ['compute the union size of two bit sets .'],
#  3: ['test 2 keys with candidates in reverse order .'],
#  4: ['responds to a closing event under an ok condition .'],
#  5: ['outputs a description of the rule .'],
#  6: ['returns a new sector whose angles are the extre mes of the this sector '
#      "and another . the new sector ' s minimum latitude and longitude will be "
#      "the minimum of the two sectors . the new sector ' s maximum latitude and "
#      'longitude will be the maximum of the'],
#  7: ['check if the value is equal to the given double value , e . g . if the '
#      'double is equal to 0 then the result is false .'],
#  8: ['integer value of a positive bigdecimal'],
#  9: ['main recursive method to examine the directory hierarchy .'],
#  10: ['get a sorted array containing all column values for a given tuple '
#       'iterator and field .'],
#  11: ['divide with invalid rounding mode'],
#  12: ['receives notification of a dataset change event .'],
#  13: ['is called when the schedule is accessible to schedule this consumer '
#       'with the provided configuration'],
#  14: ['return true if the reference type is a string type .'],
#  15: ['this method api to update the source of the given user .'],
#  16: ['validates that the given sql statement is not empty'],
#  17: ['converts to object array .'],
#  18: ['is this logger instance enabled for the trace level ?'],
#  19: ['use a percep u item from the list of players to indicate that a new '
#       'occupancy is no longer being used .'],
#  20: ['creates a new tcp matcher based on configuration values .'],
#  21: ['recursive search for the maximum number of levels of the vertex e is '
#       'returned .'],
#  22: ['ask to the user for ret yp ing the pass code just entered before saving '
#       'it as the current pass code .'],
#  23: ['rolls back the worker thread creation . - removes worker from workers , '
#       'if present - decrements worker count - re checks for termination , in '
#       'case the existence of this worker was holding up termination'],
#  24: ['insert functionality test test insert 4 ( ) . tests insert . . . select '
#       'with expressions in select query'],
#  25: ['add the entry to the disk , unless the disk has been successfully '
#       'created for the specified local id .'],
#  26: ['receive notification of the end of an element .'],
#  27: ['send a fatal error log message'],
#  28: ['delete a column which has the specified name'],
#  29: ['returns a string representation of the set .'],
#  30: ['validate the the candidate single part of the predicates table .'],
#  31: ['build the final bitmap - pieces to draw in animation'],
#  32: ['unregisters a previously acquired vm shutdown hook .'],
#  33: ['set the player thread and add them to the player'],
#  34: ['bounds the current scroll if necessary , but does not synchronize the '
#       'stack view with the model .'],
#  35: ['computes the weighted aggregate matrix for the given instance . this '
#       'method is called from junit api'],
#  36: ['blocks until the request is available for volumes to be visible . this '
#       'is a convenience method used to keep the request offline .'],
#  37: ['to be called when additional services are added to the cache .'],
#  38: ['pass through to the current state and fires any changed event , and '
#       'updates the indicator view state'],
#  39: ['paints the image on the window .'],
#  40: ['returns true if , at this time , the object will accept a connection '
#       'via the named event'],
#  41: ['indicates if this name is an unsigned character . a string is defined '
#       'to be in the format " & lt ; " , " & gt ; " .'],
#  42: ['quietly close a connection .'],
#  43: ['adds an array of actions to the quick action view'],
#  44: ['adds a simple renderer to the multiple renderer .'],
#  45: ['copies stream , fires progress events by listener , can be interrupted '
#       'by listener .'],
#  46: ['calculates the needed angle for a given value'],
#  47: ['returns a buffer to the pool , throwing away old buffers if the pool '
#       'would exceed its allo tted size .'],
#  48: ['creates a new instance .'],
#  49: ['creates a new char seq by concatenating the contents of this char seq '
#       'and the specified char seq .'],
#  50: ['the standard servlet method overridden .'],
#  51: ['notify the change of a state change , but no event .'],
#  52: ['test for get order ( ) method'],
#  53: ['formats and logs a message with a throwable .'],
#  54: ['construct the redis key used to increment the given job state .'],
#  55: ["decodes ' % ' - escaped octets in the given string using the specified "
#       'charset . replaces invalid octets with the the unicode replacement .'],
#  56: ['adds specified domain name to the list of restricted domains'],
#  57: ['create a new instance'],
#  58: ['tests fail : always returns false , failing statements commented out . '
#       'feature only partially implemented . missing : test positive case not '
#       'supported .'],
#  59: ['computes the interface hash ( 64 bit ) of the datos and writes the '
#       'result to the remote stream .'],
#  60: ['copy the contents of the given byte array to the given outputstream . '
#       'leaves the stream open when done .'],
#  61: ['does this item have any items loaded yet ?'],
#  62: ['render the frame data ( in bytes )'],
#  63: ['encode parts of the message using text compaction as described in iso / '
#       'iec 154 38 : 2001 ( e ) , chapter 4 . 4 . 2 .'],
#  64: ['check to see if a string is a valid ncname according to [ 4 ] from the '
#       'xml namespaces 1 . 0 recommendation'],
#  65: ['appends the specified element to the end of this list .'],
#  66: ['prepare the dataset required for running test cases'],
#  67: ['build a proxy service presenter using our set of proxies .'],
#  68: ['check that the given string value is valid for the array element .'],
#  69: ['metri me all primary members that are marked primary . this method will '
#       'be called as primary for each connection in the manage queue , when '
#       'primary selector is deleted .'],
#  70: ['creates a new journal that omits redundant information . this replaces '
#       'the current journal if it exists .'],
#  71: ['removes the recurrence from persistant store .'],
#  72: ['copy nodelist members into this nodelist , adding in document order . '
#       'null references are not added .'],
#  73: ['check whether data can be read . returns false if there are still data '
#       'to be read .'],
#  74: ['this method must be implemented by subclasses'],
#  75: ['services a commandline request .'],
#  76: ['convert to byte array .'],
#  77: ['conver th l typename returns a default value for the given style class '
#       '. generated derived classes will be used if the system property has a '
#       'non - null value .'],
#  78: ['check if the stream uid is already at the current position . for '
#       'example , if stream uid is < = 0 then stream uid is not valid , video '
#       'frame .'],
#  79: ['routine will generate an exportmask to be placed on the exportmask '
#       'iterator . for instance , hl u is not checked against this routine '
#       'because only one exportmask will be placed inside of a exportmask . for '
#       'instance , hl u is not checked against this member .'],
#  80: ['inserts the array at the specified index and returns a new immutable '
#       'array . if the object is already registered , then this will return '
#       'null .'],
#  81: ['write a no scale line to the graph , no scaling is required . this is '
#       'not for debugging purposes only .'],
#  82: ['put the source tree root node in the document cache . todo : this '
#       'function needs to be a lot more sophisticated .'],
#  83: ['used to communicate a progress update between a plugin tool and the '
#       'main whitebox user interface .'],
#  84: ['copy a input resource to a output resource'],
#  85: ['starts an audio of the specified type , stop / stop time and fade out '
#       'at the specified stop time .'],
#  86: ['draw into the provided canvas .'],
#  87: ['loads properties from a file descriptor .'],
#  88: ['add a number to zero'],
#  89: ['get the gps stamp do not set'],
#  90: ['returns true if the given cell was marked by the user in its own heap '
#       '.'],
#  91: ['read a single character . this method will block until a character is '
#       'available , an i / o error occurs , or the end of the stream is reached '
#       '. subclasses that intend to support efficient single - character input '
#       'should override this method .'],
#  92: ['this function is used to plot the y axis and labels related with y axis '
#       '. uses draw labels ( ) method to create y axis and draw labels related '
#       'with y axis'],
#  93: ['get the maximum value stored in this map .'],
#  94: ['this method is called from the main menu thread and executes the task . '
#       'it executes the check job with a security type performed .'],
#  95: ['extends this set of alternative ground ings with the given output '
#       'stream .'],
#  96: ['attempts to throw an exception if the specified pattern can not be '
#       'parsed .'],
#  97: ['test simple get table types order .'],
#  98: ['this method will be used to check whether stream is already present in '
#       'cache or not for file if not present then create it and then add to '
#       'cache , other wise get from cache , and then add to cache , other wise '
#       'get from cache ( )'],
#  99: ['removes a listener from the set of listeners'],
#  100: ['returns what the serialization specification calls " descriptor " '
#        'given a field signature .'],
#  101: ['adds a new list of parameters'],
#  102: ['process an annotation class name to the class . the class name is the '
#        'class name of the ordinary interface .'],
#  103: ['gets the resource support object of a given id .'],
#  104: ['a service wrapper for the create electron ict ext method method . '
#        'forces permissions to be checked .'],
#  105: ['creates a pattern expression .'],
#  106: ['compute the intersection of two line segments .'],
#  107: ['method which removes the specified object class from original set and '
#        'returns the set of object classes that were removed .'],
#  108: ['return the timestamp in milliseconds since the epoch , including '
#        'potential potential timestamps .'],
#  109: ['is this a pdf license'],
#  110: ['draws the grid background'],
#  111: ['opens a stream to an entry in the jar .'],
#  112: ['unpacks the compressed character translation table .'],
#  113: ['this method is called when the fragment has been updated from the '
#        'android vm .'],
#  114: ['this overridden method checks to see if the projection is created on '
#        "the map . if it is created , it gets the layer ' s top - left corner "
#        '.'],
#  115: ['returns common pool queue for a thread that has submitted at least one '
#        'task .'],
#  116: ['internal : returns true if this is a field package private attribute '
#        '.'],
#  117: ['divide : rounding mode is round half up , result is positive ; '
#        'distance = - 1'],
#  118: ['api method . this method performs a saved format of the parent user . '
#        'api call : post / modify args : 66 57 3 . 0 stream the user id and '
#        'password args are not checked .'],
#  119: ['this method will be invoked when the current page is scrolled , either '
#        'as part of a programmatically initiated smooth scroll or a user '
#        'initiated touch scroll . if you override this method you must call '
#        'through to the superclass implementation ( e . g . super . onpage '
#        'scrolled'],
#  120: ['convert a human readable string that can be returned in a general form '
#        '. a quoted string can be converted to a general form .'],
#  121: ['loads the lts read from the column file .'],
#  122: ['calculate selector radius the selector radius can be calculated by a '
#        'simple math calculation of the larger side .'],
#  123: ['determines the width of this view'],
#  124: ['test bulk get / put byte [ ] methods'],
#  125: ['called when the object is added .'],
#  126: ['parser for the local number .'],
#  127: ['transforms multiple paths will all matrices .'],
#  128: ['decodes a byte array from base 64 format . no blanks or line breaks '
#        'are allowed within the base 64 encoded input data .'],
#  129: ['ensures the truth of an expression involving the state of the calling '
#        'instance .'],
#  130: ['item will slide from top of the screen to its natural position .'],
#  131: ['constructs a new mutable biginteger with the given mutable biginteger '
#        'visibility .'],
#  132: ['handle request sent with a wrong binding'],
#  133: ['take an inputstream an input stream'],
#  134: ['load from the store .'],
#  135: ['returns a string to close after writing to mysql startup , so always '
#        'returns null .'],
#  136: ['puts the given parameter value into a new list object .'],
#  137: ['returns the minimum dimensions the target container can use to lay out '
#        'the components it contains .'],
#  138: ['non symmetric reduction to cbc cbc cbc mechanism .'],
#  139: ['selects the view at the given position in the selections list . if '
#        'position is already in the selection , it is selected .'],
#  140: ['returns an enumeration describing the available options .'],
#  141: ['if the text nodes is not collapsed , either the start and end of the '
#        'template or end of the template text . any text nodes are not '
#        'considered ignorable .'],
#  142: ['waits for the given page to be active in the internal file editor'],
#  143: ['returns the largest solution value in the population expressed by the '
#        'specified objective and returns the result .'],
#  144: ['converts latitude ( in world ) coordinates to x location in world '
#        'coordinates .'],
#  145: ['register listener with the passed notification id , creating the web '
#        'object listener if necessary .'],
#  146: ['parses an ascii property list from an input stream .'],
#  147: ['current chi - squared scoring function .'],
#  148: ['creates a new gram mat ical ity estimator , using a given set of '
#        'documents for training .'],
#  149: ['check if the zone link is in the set of forms to display the zone link '
#        '.'],
#  150: ['this checks the next sample using cumulative probability and also '
#        'ensures that the sample size ( cumulative probability is at least one '
#        'sample size ) .'],
#  151: ['checks that the given array is a valid weight vector .'],
#  152: ['measure and layout all currently visible children .'],
#  153: ['processes the connection events .'],
#  154: ['gets the percent value in the specified range .'],
#  155: ['closes the passed in resource if not null .'],
#  156: ['releases an existing page context'],
#  157: ['adds a new event listener to this dialog .'],
#  158: ['we only rebuild the journal when it will hal ve the size of the '
#        'journal and eliminate at least 2000 ops .'],
#  159: ['converts string to byte array'],
#  160: ['this method will load the properties from a file or subdirectory using '
#        'the supplied classpath .'],
#  161: ['tests the object for equality with this object .'],
#  162: ['parses a name - value - pair with the given parser .'],
#  163: ['actions a pull event'],
#  164: ['returns the mapping object at the given location'],
#  165: ['parse the template and return the result .'],
#  166: ['find the differences between two texts . simplifies the problem by '
#        'stripping any common prefix or suffix off the texts before diff ing .'],
#  167: ['creates a new instance for a given domain'],
#  168: ['returns the number of unprocessed tokens remaining in the string .'],
#  169: ['runs the code index document . this method will run the code index '
#        'document at the tail of the index document .'],
#  170: ['reset all common components before parsing'],
#  171: ['updates the labels based on the passed src and tenant uri .'],
#  172: ['handles a exception that is thrown by the user .'],
#  173: ['create the object after serialization . this implementation '
#        'reinitializes the transient properties .'],
#  174: ['paint the arrow in enabled state .'],
#  175: ['logs a thrown exception .'],
#  176: ['convert a small bigdecimal to biginteger'],
#  177: ['called when the accuracy of the sensor has changed .'],
#  178: ['can this parser require trailing arguments ?'],
#  179: ['setmax crl number ( biginteger max crl ) method testing . tests if '
#        'crls with any crl number value match the selector in the case of null '
#        'crl number criteria , if specified max crl value matches the selector '
#        ', and if crl with inappropriate crl number value does not'],
#  180: ['if this is the popup trigger , evaluate the popup menu . otherwise , '
#        'defer to the superclass .'],
#  181: ['removes the given task , ignoring min and min at least it is greater '
#        'than min , so that it is discarded . if at least one task is found , a '
#        'new task is created , so an existing task is started , running first '
#        'task in the list'],
#  182: ['java . math . bigdecimal divide ( java . math . bigdecimal , java . '
#        'math . roundingmode ) divide ( bigdecimal , roundingmode )'],
#  183: ['ensures that path does exist'],
#  184: ['the class loader is the package whose name resolve is the name .'],
#  185: ['determines the height of this view'],
#  186: ['this only checks clipping along the bottom edge .'],
#  187: ['creates a new scheduling rule factory for the given workspace'],
#  188: ['writes a byte array to a file creating the file if it does not exist '
#        '.'],
#  189: ["adds the specified item to the adapter ' s list ."],
#  190: ['check to see if any pending messages are pending'],
#  191: ['determines the number of consecutive characters that are encodable '
#        'using numeric compaction .'],
#  192: ['parses the current node and returns the number of elements added .'],
#  193: ['calculate the multiplier for the current k - s , according to the '
#        'current action type'],
#  194: ['test for verifying that assert that assert that assert numeric turned '
#        'on can also be used concurrently , instead of false'],
#  195: ['closes the cache callback , invoked when a cache loader is closed .'],
#  196: ['static version of indexof , to allow repeated calls without needing to '
#        're - acquire array each time .'],
#  197: ['populate the setting of profiles .'],
#  198: ['check to see whether the file header exists within the comms data '
#        'generator and if so , we determine the number of magic moves .'],
#  199: ['absolute value of real component'],
#  200: ['internal extre mum function .'],
#  201: ['maps alg name to oid'],
#  202: ['provide reflective behavior to construct instance of generator given '
#        'an array of string arguments .'],
#  203: ['refills the input buffer .'],
#  204: ['overridden so we can exit when the mouse is released .'],
#  205: ['add a module to the set of modules to load and register its services'],
#  206: ['determines if the database has all tables defined'],
#  207: ['classifies an attempt to process the input box . return a list of '
#        'string , list of string , string , list of any transformed string , '
#        'and string , which is encoded using the methods provided in sequence '
#        '.'],
#  208: ['to bind different types of headers and headers to the given holder'],
#  209: ['update the arrow list buttons .'],
#  210: ['draws a rectangle of given half width and half height , centered on ( '
#        'x , y ) .'],
#  211: ['re - measure the loading views height , and adjust internal padding as '
#        'necessary'],
#  212: ['replaces the element with a split element'],
#  213: ['called to start adding an item to an item list .'],
#  214: ['returns the odd number of initial aspectratio for the split .'],
#  215: ['invoked when a mouse button has been clicked on a component .'],
#  216: ['scans the path to scan files for source files .'],
#  217: ['returns true if there is another postpon ed route to try .'],
#  218: ['return whether there are no elements in the list'],
#  219: ['convert from a uri to an ex path .'],
#  220: ['reads a xml element attribute ans cast it to a int value'],
#  221: ["returns the remainder of ' reader ' as a string , closing it when done "
#        '.'],
#  222: ['this method is only used for constants that are assigned to other '
#        'classes .'],
#  223: ['mark a entry as used .'],
#  224: ['execute a full text command .'],
#  225: ['handles the delay to join the token , such as token , availability and '
#        'expire time .'],
#  226: ['registers implementing class of the signature algorithm with algorithm '
#        'uri'],
#  227: ['reads settings from the configuration file . restore it when new '
#        'settings are created .'],
#  228: ['tell if the string contains a word breaking character .'],
#  229: ['checks whether all segments string contains interior segments or '
#        'fragments'],
#  230: ['removes the first occurrence , starting at the beginning and moving '
#        'towards the end , of the specified object from this vector . all '
#        'elements with an index bigger than the element that gets removed have '
#        'their index decreased by 1 .'],
#  231: ['compose this operator by applying the supplied function , passing each '
#        'one after the other'],
#  232: ['adds a new c dc col specifications after the meta - data . in case of '
#        'columns , the meta - data is already a multi - row after that position '
#        '.'],
#  233: ['converts a name that is non - empty string into a java field name . '
#        'this is in the use of the java getter methods , and will silently '
#        'convert it to a java field name .'],
#  234: ['a function that generates random aes & hmac keys and prints out '
#        "exceptions but doesn ' t throw them since none should be encountered . "
#        'if they are encountered , the return value is null .'],
#  235: ['ensures the truth of an expression involving one or more parameters to '
#        'the calling method .'],
#  236: ['execute a full text statement with a database after keys , and change '
#        'to be performed .'],
#  237: ['creates a new journal that omits redundant information . this replaces '
#        'the current journal if it exists .'],
#  238: ['updates the error state when done'],
#  239: ['create the migration task editor .'],
#  240: ['this method will be invoked when the current page is scrolled , either '
#        'as part of a programmatically initiated smooth scroll or a user '
#        'initiated touch scroll . if you override this method you must call '
#        'through to the superclass implementation ( e . g . super . onpage '
#        'scrolled'],
#  241: ['used to communicate a progress update between a plugin tool and the '
#        'main whitebox user interface .'],
#  242: ['ensures there is enough space in the buffer for the given number of '
#        'additional bytes .'],
#  243: ['accepts an ipv 4 address of the form xxx . xxx . xxx . xxx , ie 192 . '
#        '168 . 0 . 1 and returns the corresponding 32 bit integer .'],
#  244: ['close the given cursor and remove it from the map'],
#  245: ['returns true if the pattern matches the given pattern .'],
#  246: ['generates the instruction to push the given integer on the stack .'],
#  247: ['return the compact xml node , with prefix and value . if the given '
#        'name is null , the given attributes will be returned .'],
#  248: ["adds a new item to the adapter ' s list"],
#  249: ['notify unsuccessful completion of the operation'],
#  250: ['transform an xsl - fo streamsource to the specified output format .'],
#  251: ['parses the input string using the default delimiter character .'],
#  252: ['reads next data from the reader , with blocking enabled . if there is '
#        'still data to be available blocking , will return false . if the data '
#        'is failed to be read , will return false'],
#  253: ['the obligation defines the disconnected - engines , removes all of the '
#        "inter umla ings ' s updated states ."],
#  254: ['set bounds for the right textview including clip padding .'],
#  255: ['creates a compound package content object .'],
#  256: ['checks if all uniform cluster indices can be included in an coverage '
#        'file .'],
#  257: ['find the values in the metric name .'],
#  258: ['returns the first index of elt in the array if < len , else - 1 .'],
#  259: ['append a value to a list . note that this is an unsupported map , it '
#        'is not used to put the list .'],
#  260: ['compares the argument to this certificate . if both have the same '
#        'bytes they are assumed to be equal .'],
#  261: ['appending the between clause with one or more table name .'],
#  262: ["encode the string ' s x position into a byte array ."],
#  263: ['used to communicate a progress update between a plugin tool and the '
#        'main whitebox user interface .'],
#  264: ['convert from a gts to a map , which is used to store the value '
#        'associated with a geo time serie instance ( reference : 5 , 4 , 0 , 1 '
#        ', 4 ) into a map & lt ; = value & gt ; = value .'],
#  265: ['this function will take a song entry and update it to the latest week '
#        'and increase the count for the current week by 1 if necessary'],
#  266: ['recursively assign node weights .'],
#  267: ['creates a new instance of search engine'],
#  268: ['adds a field to the query . a field may contain a null field or an '
#        'empty string .'],
#  269: ['concatenate two completion stage together'],
#  270: ['build the create schema statement for use with load .'],
#  271: ['( for a negative and a positive numbers ; the first is shorter'],
#  272: ['creates a new instance'],
#  273: ['sentence to parse .'],
#  274: ['determine if the expression consists of normalizing words .'],
#  275: ['output the sql type for a java short .'],
#  276: ['breaks a string to multiple strings .'],
#  277: ['write all modified favorites to the data stream .'],
#  278: ['notify the counter of connections that have been reached .'],
#  279: ['make sure that the payment product is valid'],
#  280: ['a helper function to load the state of keystore as a child keystore '
#        'state .'],
#  281: ['construct a new crypto result with the given result .'],
#  282: ['invoked when the target of the listener has changed its state .'],
#  283: ['parses a delimited list of strings into a list'],
#  284: ['initialize the gui layout of the dialog .'],
#  285: ['indicates whether this thread is running .'],
#  286: ['creates a default mosaic definition .'],
#  287: ['internal method to handle a single select query .'],
#  288: ['makes http sur lconnection trust manager trust manager tru sts trust '
#        'manager that are enabled for all of the certificates specified by the '
#        'keystore .'],
#  289: ['check if the component is in the navigation pane . if it is an '
#        'editable value holder , it is considered a text , other than can be '
#        'used to edit the text area .'],
#  290: ['add internal listeners to the distribution .'],
#  291: ['the " safe " square root of the input value , handling negative values '
#        'by simply making them positive and then neg ating the return value .'],
#  292: ['runs threads on a single thread .'],
#  293: ['appends a single character to buffer . if there is enough characters '
#        'to m buffer , the characters of m buffer will be added to m buffer .'],
#  294: ['import all relations for the field using the provided information .'],
#  295: ['construct a select statement suitable for use in a group of select '
#        'statements that will be joined through union operators in build union '
#        'query .'],
#  296: ['creates a new node with the given coordinate , and no edges .'],
#  297: ['add new accuracy when the buffer is full , using clear accuracy method '
#        '.'],
#  298: ['revert to root by working directories'],
#  299: ['concatenates a list of float arrays into a single array .'],
#  300: ['this is used for testing the processing of the embe ts text .'],
#  301: ["removes the root tree from empty jar if it ' s not present in the "
#        'filesystem . a non - empty path will be used otherwise .'],
#  302: ['the holder can read .'],
#  303: ['writes the contents of the internal buffer to the given array starting '
#        'at the given offset . assumes the array has space to hold count bytes '
#        '.'],
#  304: ['called when item was removed .'],
#  305: ['computes the pdf of the distribution'],
#  306: ['sorts an array of strings , returning a new array with the sorted '
#        'items . the original array is left untouched .'],
#  307: ['adds a new zoom listener .'],
#  308: ['clears the registers in a given instruction range for each register in '
#        'the operand table for each instruction that is no longer a ( improper '
#        ') register .'],
#  309: ['fire when the something minor with workflow annotations has been '
#        'selected .'],
#  310: ['updates the prediction stats and returns whether prediction is allowed '
#        '. the policy is : 1 . if the client does not wait more than m delay ms '
#        ', decline the request . 2 . if the client waits for more than m delay '
#        'ms but less than 2 m'],
#  311: ['authenticates the received server evidence message and saves it only '
#        'if correct . to be called after calculating the secret s .'],
#  312: ['this is fired when a text is received from a server . this method is '
#        'invoked by the server when something is pressed from a server .'],
#  313: ['removes a service uri from the list of services marked as custom '
#        'services'],
#  314: ['scipio : converts a string reference into attribute'],
#  315: ['constructs an escap ed writer around the given writer .'],
#  316: ['returns true if this cookie has expired .'],
#  317: ['records the hierarchy of the given record builder into the log file'],
#  318: ['compares two methods by signatures .'],
#  319: ['remainder of division of equal numbers'],
#  320: ['method called to remove all encodings and getter settings'],
#  321: ['\\ brief distance ( a , b )'],
#  322: ['check if backup info file was loaded from the backup'],
#  323: ['a locale independent version of tolowercase .'],
#  324: ['create a negative number from a sign and an array of bytes . the '
#        'number of bytes is 4 . the most significant byte is positive .'],
#  325: ['builds and returns a opus comment .'],
#  326: ['fails if the first message is equal to the second occurrence of the '
#        'second event . this method is used to invoke the other method .'],
#  327: ['size of this set'],
#  328: ['converts a string to upper case , where the first character is the '
#        'uppercase uppercase of the string .'],
#  329: ['creates an iterator over the required edges .'],
#  330: ['unlocks the current thread .'],
#  331: ['creates and returns a string formatted so it will fit in a box '
#        'suitable for a java doc header .'],
#  332: ['force a number to two digits . if the number contains two digits , '
#        'only the given string is returned .'],
#  333: ['add a droptarget item to the list , with a specified name and a '
#        'probability of existing probability .'],
#  334: ['finds all base keys by its primary keys .'],
#  335: ['load work fl w and initialize the session attributes .'],
#  336: ['returns a hash code value for this x509 certificate from its encoded '
#        'value .'],
#  337: ['removes the from tags .'],
#  338: ['verify the given sec p 256 k 1 signature in native code'],
#  339: ['recursively delete the webapp directory .'],
#  340: ['tests that the iterator visits the specified objects , regardless of '
#        'the order in which the iterator is exhausted .'],
#  341: ['if the tmp finished percentage is in the progress bar , then it checks '
#        'the finished percentage .'],
#  342: ['generates the hostname portion of the vm name , based on hostname and '
#        'host .'],
#  343: ['transfers each line of an id file from the data file'],
#  344: ['helper method for over scrolling that encapsulates all of the '
#        'necessary function . this is the advanced version of the call .'],
#  345: ['removes part of the expression .'],
#  346: ['if we have all pi echart config then there is no point in reloading '
#        'it'],
#  347: ['draws the next event time difference , returning the limit to use .'],
#  348: ['creates the line structure for the given text . newly created lines '
#        'are inserted into the line structure starting at the given position . '
#        'returns the number of newly created lines .'],
#  349: ['returns the positive square root of the specified value .'],
#  350: ['counts the number of black / white transitions between two points , '
#        "using something like b res enh am ' s algorithm ."],
#  351: ['convert a number into a bit string .'],
#  352: ['encodes an array of bytes into an array of url safe 7 - bit characters '
#        '. unsafe characters are escaped .'],
#  353: ['the core class has disposed of the message deserializer class to '
#        'create as a line segment .'],
#  354: ['this method waits until there is no locks to occur . blocks until a '
#        'node that that is not already snow ed'],
#  355: ['updates translation cache if needed , or sets the translation into '
#        'empty .'],
#  356: ['creates a new navigation mouse mode with the provided configuration'],
#  357: ['adds a new event to the simulation .'],
#  358: ['stops the timer with the specified name .'],
#  359: ['returns the summary as string .'],
#  360: ['creates a temporary path in the specified directory . it will be '
#        'created if the file exists is not created .'],
#  361: ['plots a text range and the legend'],
#  362: ['select also all items belonging to any connection of the current '
#        'selected items .'],
#  363: ['builds a key builder for the given capacity and mode'],
#  364: ['removes from the list of nodes any that cannot be parents of x given '
#        'the background knowledge .'],
#  365: ['reads properties from a properties stream , and sets the prefix and '
#        'prefix'],
#  366: ['open a new connection to the database .'],
#  367: ['a simple implementation of the add relations method which presents the '
#        'general concept of the method . it should not be used in production '
#        'because of possible race condition - production ready code should '
#        'perform an atomic operation .'],
#  368: ['updates actively adds active flow to the switch switch . flow is '
#        "called in the main ' s domain list . the delta list can be called in "
#        'the future . the idea is responsible for creating one flow in the '
#        'autop some switch . the autop ine is called'],
#  369: ['sleep for the specified time , ignoring any exceptions that occur'],
#  370: ['explicitly checks whether the write set was found . this should never '
#        'be called outside the test set .'],
#  371: ['calculates the entropy of a given masses .'],
#  372: ['check to see if a string is a valid nmtoken according to [ 7 ] in the '
#        'xml 1 . 0 recommendation'],
#  373: ['handles the event , replacing the modifier that was pressed by the '
#        'user .'],
#  374: ['parses a double value from the given string , j toffset and datatype '
#        '.'],
#  375: ['puts a string in the byte array .'],
#  376: ['actions a pull event'],
#  377: ['add a rtcp event listener'],
#  378: ['creates a new array of the given size if necessary and copies the data '
#        'into the new array .'],
#  379: ['this method detects a code in a " pure " image - - that is , pure mono '
#        'chrome image which contains only an un rotated , un skewed , image of '
#        'a code , with some white border around it . this is a specialized '
#        'method that works exceptionally'],
#  380: ['report an one argument error .'],
#  381: ["connects socket ' fd ' to ' inetaddress ' on ' port ' , with no "
#        "timeout . the lack of a timeout means this method won ' t throw socket "
#        'timeoutexception .'],
#  382: ['determine if the string - value of a node is whitespace'],
#  383: ['creates a new status panel object .'],
#  384: ['parses the image file .'],
#  385: ["deregisters a spring from this base spring system , so it won ' t be "
#        'iterated anymore . the spring should not be used anymore after doing '
#        'this .'],
#  386: ['returns the name of the source file or jar file , if any .'],
#  387: ['parses an n - triples b node , creates an object for it using the '
#        'supplied value factory and returns this node .'],
#  388: ['resets the ps r list .'],
#  389: ['sorts the specified array in ascending numerical order .'],
#  390: ['close this popup menu .'],
#  391: ['frees a previously generated object'],
#  392: ['expand the view horizontally to the size of the cross size ( '
#        'considering the view margins )'],
#  393: ['convert a string of hexadecimal digits to an address .'],
#  394: ['track a failure - multiply the back off interval by the multiplier'],
#  395: ['reads a double ( 64 bit ) from the source stream .'],
#  396: ['returns true is the specified bar is at the maximum of the bar .'],
#  397: ['case sensitive match test .'],
#  398: ['method to parse a tile set'],
#  399: ['computes the result for a double input value .'],
#  400: ['enables a pan and checks to make sure that the pan is set to the '
#        'correct state .'],
#  401: ['return the distance between two points'],
#  402: ['creates a new url of the given component parts . the url uses the '
#        "protocol ' s default port ."],
#  403: ['return a workflow . method for create volume s method .'],
#  404: ['creates a new file command info object with content'],
#  405: ['initialize this doc repository for the given manual manual manual '
#        'manual manual widget'],
#  406: ['this function will install a trust manager that will blindly trust all '
#        'ssl certificates . the reason this code is being added is to enable '
#        'developers to do development using self signed ssl certificates on '
#        'their web server . the standard http sur lconnection class will throw '
#        'an exception on'],
#  407: ['sample the active count'],
#  408: ['gets a reference to the oauth service auth module .'],
#  409: ['test for correct error handling for a mission with no " name " '
#        'attribute .'],
#  410: ['checks if this object equals another . the entire state of the object '
#        'is compared .'],
#  411: ['releases any resources we may have ( or inherit )'],
#  412: ['compute the monte - normal distribution . based on the equation " '
#        'numerical recipes " method .'],
#  413: ['close the current output stream and release any resources associated '
#        'with it'],
#  414: ['resolves all files with the given prefix and all files .'],
#  415: ['javax / crypto / exemp tion mechanism getinstance ( string algorithm , '
#        'string provider ) checks exception order'],
#  416: ['reloads all configuration settings and recreates the session .'],
#  417: ['removes the message processor and starts it running if one is '
#        'currently running .'],
#  418: ['creates an x509 crl serial from the specified certificate .'],
#  419: ['writes the set to an existing file .'],
#  420: ['put a byte array in the buffer .'],
#  421: ['returns a delimited string of the given array , separated by delimiter '
#        '.'],
#  422: ['removes all items from the stag ing area .'],
#  423: ['parse rrggbb color from a string .'],
#  424: ['factory method to create a new tel state'],
#  425: ['returns the size in bytes ( shared enough to hold the old buffer ) for '
#        'the old instance .'],
#  426: ['read from the file . this method will block until some input is '
#        'available , an i / o error occurs , or the end of the file is reached '
#        '. subclasses that intend to support efficient single - character input '
#        'should override this method .'],
#  427: ['if the normalized scale is equal to 1 , then the image is made to fit '
#        'the screen . otherwise , it is made to fit the screen according to the '
#        'dimensions of the previous image matrix . this allows the image to '
#        'maintain its zoom after rotation .'],
#  428: ['limit the clip such that it fits within the specified region .'],
#  429: ['shutdown all thread pools .'],
#  430: ['accepts host addresses and all provided addresses .'],
#  431: ['removes all occurrences of a \\ n and \\ r \\ n from the string .'],
#  432: ['calculate number of times to write to each file in the all programming '
#        'code . extracts the number of times and writes to the database , and '
#        'increments the number of counters to keep track of the file ; that is '
#        ', calculate the number of calls to write par'],
#  433: ['escape character character to html .'],
#  434: ['loop through the current table and all each of the columns in the '
#        'current table .'],
#  435: ['retrieves row count of a given table .'],
#  436: ['creates a new jar modifier with the given archive to be modified'],
#  437: ['adds an attribute to the table .'],
#  438: ['associate the given value with the specified key .'],
#  439: ['sort the specified array of the top n elements into ascending order .'],
#  440: ['tells whether or not this connection is a server transaction .'],
#  441: ['adds a special " marked occurrence " highlight .'],
#  442: ['helper method for over scrolling that encapsulates all of the '
#        'necessary function . this is the advanced version of the call .'],
#  443: ['blocks till the given number of bytes have been read from the given '
#        'inputstream .'],
#  444: ['validate the given assumption .'],
#  445: ['adds a set of results to the cart'],
#  446: ['add a frequent item set .'],
#  447: ['skip characters from the peek buffer'],
#  448: ['a method that creates the workflow method to remove the volumes of a '
#        'vplex consistency group .'],
#  449: ['works only for unix url . show urls which are directly presented to '
#        'the user .'],
#  450: ['convert mouse mouse button to appropriate step . this is necessary for '
#        'the illegal manner when the mouse is released .'],
#  451: ['recursively converts a string like " [ " , " ] " to " [ " , " [ " , " '
#        '+ " ] and returns the result .'],
#  452: ['generate a call identifier in advance of the form " raw " .'],
#  453: ['parse a hour value . depending on pattern char parameter , the hour '
#        'can be 0 - 23 , 1 - 24 , 0 - 11 , or 1 - 12 . the returned value will '
#        'always be 0 based .'],
#  454: ['this method should handle a get command history from the user .'],
#  455: ['determine the types of an original type , that is , is , the copying '
#        'of substitution . get substituted ( ) .'],
#  456: ['this is where magic happens as you know .'],
#  457: ['returns all available endpoints for all endpoints .'],
#  458: ['returns the seconds until idle lock out .'],
#  459: ['this method is called via reflection from the database .'],
#  460: ['or for two negative numbers ; the first is shorter'],
#  461: ['from numerical recipes in the kernel domain , i . e . , for h = 1 / h '
#        ';'],
#  462: ['read the object from base 64 string .'],
#  463: ['copy an existing document from one document to another . if the '
#        'document is not already removed , the document is not deleted .'],
#  464: ['construct a matrix with the given argument . the matrix argument is '
#        'always created'],
#  465: ['unlock the specified internal distributed member for clear . this '
#        'method is called in the order that they are notified of any pool nodes '
#        ', so any node may cause an exception to be thrown .'],
#  466: ['create a new ( empty ) unicast ref .'],
#  467: ['static version of lastindexof .'],
#  468: ['write current wave file to file , starting from index 0 ( inclusive ) '
#        'to the file as utf - 8 . the channel is empty when no more data is '
#        'written .'],
#  469: ['returns the d mod d - squared cdf'],
#  470: ['max ( biginteger val ) . the first is less .'],
#  471: ['function used to stop code that calls accept dataset . this is needed '
#        'as clusterer construction is performed inside a separate thread of '
#        'execution .'],
#  472: ['called to set the offset grab point to the current mouse location , '
#        'and add the point to the end of the polygon . should be called only '
#        'for all the other polygon / polygon modes .'],
#  473: ['writes floats from the given float array , starting from the specified '
#        'offset , to the current position and increases the position by the '
#        'number of floats written .'],
#  474: ['the optimized version of sax 2 dtm . dispatch character se vents ( int '
#        ', boolean ) . directly call the characters method on the passed '
#        'contenthandler for the string - value of the given node ( see http : / '
#        '/ www . w3 . org / tr /'],
#  475: ['initializes an ip address for the contain two bits .'],
#  476: ['accessed via reflection . do not remove'],
#  477: ["check if the cookie ' s cookie is one of : - cookie - name is less or "
#        'equal to known authentication cookie'],
#  478: ['choose the imported file contents of an import file .'],
#  479: ['creates a new item using the given data offset and offset .'],
#  480: ['returns an enumeration describing the available options .'],
#  481: ['encodes the application data into ssl / tls record . if handshake '
#        'status of the engine differs from not handshaking the operation can '
#        'work without consuming of data . for more information about handshake '
#        'data see tls v 1 specification ( http : / / www . w3 . org'],
#  482: ["returns a byte [ ] containing the remainder of ' in ' , closing it "
#        'when done .'],
#  483: ['parse the sql statement and locate any placeholders or named '
#        'parameters . named parameters are substituted for a jdbc placeholder . '
#        'this method may skip any placeholders and query parameters or full '
#        'parameters .'],
#  484: ["writes a long at the specified offset from this native object ' s base "
#        'address .'],
#  485: ['this is used to stop permanently typing the gc lock on whether the '
#        'request has been removed from this server or not . this is used to '
#        'stop the gc once the request has been removed from the server .'],
#  486: ['generate a salt for use with the bcrypt . hash pw ( ) method'],
#  487: ["if possible , validate the given key ' s hashcode against any that was "
#        'returned by the peer .'],
#  488: ['convert a string to a form g . 50 .'],
#  489: ['runs a script ( including the current executing if required ) . if the '
#        'argument url is null and the argument connection must be the same . '
#        'this can be used only for named scripts . if the argument is null and '
#        'the action fails with null arguments , execute'],
#  490: ['parse an integer located between 2 given offsets in a string'],
#  491: ['prints an object to this output stream and then terminates the line .'],
#  492: ['check that the given array is a real number .'],
#  493: ['init and init the keyboard buttons . if a button is found this will be '
#        'added to the stack , you only need to get the " this " button visible '
#        'on the stack .'],
#  494: ['is window autocommit ( if not set use default )'],
#  495: ['returns the full ( relative ) path to a file in the specified '
#        'directory path relative to the current directory path .'],
#  496: ['initialize the replay controller with appropriate configuration'],
#  497: ['internal method to perform the normalization .'],
#  498: ['reset the singleton , returning the resource to null . this method is '
#        'called on the beginning of the transaction manager , so that it can be '
#        'reused and stale resources present .'],
#  499: ['and not for two negative numbers ; the first is longer'],
#  500: ['generate a string of characters .'],
#  501: ['create the exchange rate manager .'],
# ...
#         'value given . if the tag value is not equal to any of the attribute '
#         'then it is considered a match to the'],
#  8519: ['returns a string representation of the business object data key .'],
#  8520: ['returns true if the given ifd is a valid ifd .'],
#  8521: ['create a energy usage object from the properties file'],
#  8522: ['if an object has a enclosing type , some function call with the name '
#         ", and the value of it ' s name , otherwise look for an object for the "
#         'first thing the method invocation is repeatedly moved .'],
#  8523: ["dispatches the beginning of an iso image command with ' iso - ' in "
#         'the given directory ( in order to run an iso - page ) .'],
#  8524: ['create an observable event with the given parameters .'],
#  8525: ['instantiates a new revision .'],
#  8526: ['remove notification of the specified type'],
#  8527: ['unify all the child outliers of a child container .'],
#  8528: ["adds uuid node and sets them as ' uuid ' ."],
#  8529: ['removes wheel changing listener'],
#  8530: ["gets the raw byte offset from the start of an object ' s memory to "
#         'the memory used to store the indicated instance field .'],
#  8531: ['determines the number of consecutive characters that are encodable '
#         'using numeric compaction .'],
#  8532: ['generates the xml representation of the object ( without xml headers '
#         'or enclosing plist - tags ) .'],
#  8533: ['when the window closes , stop any sequences running'],
#  8534: ['returns a new instance which has the additional source to be merged '
#         "together with the current array of sources . this operation doesn ' t "
#         'change the current flux merge instance .'],
#  8535: ['shutdown the server and delete all resources .'],
#  8536: ['test if the provided local id is a local id .'],
#  8537: ['starts up the server socket .'],
#  8538: ['checks for interrupt , returning throw ie if interrupted before '
#         'signalled , re interrupt if after signalled , or 0 if not interrupted '
#         '.'],
#  8539: ['clear the output builders .'],
#  8540: ['reads an archived string , based on its type'],
#  8541: ['writes carri ers and their plans into a xml - file .'],
#  8542: ['removes a listener from the system'],
#  8543: ['test that a manifest without an activity with a launcher intent has '
#         'no warnings .'],
#  8544: ['appends message if the given name is similar to the candidate .'],
#  8545: ['writes the header of the file'],
#  8546: ['returns the vendor for the jvm used to generate this build .'],
#  8547: ['creates an instance of a voice result .'],
#  8548: ['returns the backoff with the given root and its associated value .'],
#  8549: ['add the given node for the tree .'],
#  8550: ['adds the specified listener to the list of listeners that will be '
#         'notified of drawer events .'],
#  8551: ['edit a note in the six - carlo way'],
#  8552: ['adds a new entry to this tex enode .'],
#  8553: ['un hide the action bar'],
#  8554: ['formats the time in milliseconds to a hh : mm : ss string format .'],
#  8555: ['encoding loop . provides the audio track thread to get audio data . '
#         'in the case of an audio track , the recording will be done by the '
#         'audio track callback thread .'],
#  8556: ['used to check whether there is a specialized handler for a given '
#         'intent .'],
#  8557: ['set bounds for the right textview including clip padding .'],
#  8558: ['pkcs - bell coefficients for equality . see qu ve : " decon '
#         'introduction : k , p ( p ) in c , ml - decon - decon - decon den ve , '
#         'and q inv ( p ) " ( taken from : / / github . com'],
#  8559: ['remove / collapse multiple newline characters'],
#  8560: ['readobject is called to restore the state of the exec permission from '
#         'a stream .'],
#  8561: ['returns the total of the values in one column of the supplied data '
#         'table .'],
#  8562: ['open the analysis of a file and saves the settings'],
#  8563: ['beancontext membership listener method . called when objects have '
#         'been removed from the parent beancontext .'],
#  8564: ['performs some processing on the given item .'],
#  8565: ['removes instances from containers during scaling down'],
#  8566: ['draws a a normal message .'],
#  8567: ['kill all throttling sent by the player .'],
#  8568: ['start listening for changes in the registry .'],
#  8569: ['return a set with the given flags .'],
#  8570: ['defines a new package using the information extracted from the '
#         'specified manifest .'],
#  8571: ['parse an individual ph ms document and optionally starts with the '
#         'underlying stream .'],
#  8572: ['verifies the signature bytes .'],
#  8573: ['adds a regular expression to the list of matched strings .'],
#  8574: ['closes the cache and deletes all of its stored values . this will '
#         "delete all files in the cache directory including files that weren ' "
#         't created by the cache .'],
#  8575: ['returns the time ago that was passed since the given time was passed '
#         ', in milliseconds .'],
#  8576: ['converts a hex string to an array of bytes .'],
#  8577: ['stops tracking jobs from the list of job to indicate they are running '
#         '.'],
#  8578: ['returns the percent - of - variance'],
#  8579: ['transfers node , if necessary , to sync queue after a cancelled wait '
#         '. returns true if thread was cancelled before being signalled .'],
#  8580: ['returns a string representation of this set . ( that is , the '
#         'description of this set statement )'],
#  8581: ['creates a new toolkit , which will determine the default version of '
#         'the version the jvm has ( or any ) . all orders with the same keys '
#         'will be detected until the version number has been found .'],
#  8582: ['should be called by attributes or other classes to update the default '
#         'values of the upgrade attribute .'],
#  8583: ['returns a conventional generalname object , converted to the given '
#         'canonical name .'],
#  8584: ['emit a method that ensures a collection is initialized .'],
#  8585: ['unregisters client from this object and unregisters it from the list '
#         'of clients .'],
#  8586: ['encodes quotes for a resource .'],
#  8587: ['allocates a new container with the given capacity and padding'],
#  8588: ['check if uri represents local resource'],
#  8589: ['check if min e sh after is present . if it is , we need to bypass it '
#         'to send post requests'],
#  8590: ['waits for the file at the given path to be located at the given '
#         'filename'],
#  8591: ['volume is not a zone level resource'],
#  8592: ['validate if the message is of the specified type with the expected '
#         'type .'],
#  8593: ['close fetch fetch object and counter'],
#  8594: ['calculates the md 5 hash of the provided message using the specified '
#         'hash function .'],
#  8595: ['runs the bifur cer compare job from a table list path .'],
#  8596: ['helper method for over scrolling that encapsulates all of the '
#         'necessary function . this is the advanced version of the call .'],
#  8597: ['deletes sub - personid containers .'],
#  8598: ['test of find recent message ide method , of class hbase message '
#         'mapper .'],
#  8599: ['queue an " event " to be run on the gl rendering thread .'],
#  8600: ['creates an error message .'],
#  8601: ['ensure that the buffer has at least capacity to hold the target size'],
#  8602: ['writes the given bytes to the binary output .'],
#  8603: ['timing target implementation : calculate and set the current car '
#         'position based on the animation fraction'],
#  8604: ['process the source tree to the output result .'],
#  8605: ['processes a " query " using a user constructed solr queryrequest , '
#         'and closes the request at the end .'],
#  8606: ['determines if the two links have the same link stats .'],
#  8607: ['generate a string to be used in amazon .'],
#  8608: ['removes the provider at the specified 1 - based position .'],
#  8609: ['this parses an element and returns a object representing the data .'],
#  8610: ['instances should not be constructed in standard programming .'],
#  8611: ['formats the given money representing a micro amount into a string'],
#  8612: ['delete an instance of the entry class , and remove the class from '
#         'entry classes if this is the last such instance .'],
#  8613: ['loads the settings and stores them in a properties map .'],
#  8614: ['log a warning message using the logger of this interpreter ( logger '
#         'level : warning ) .'],
#  8615: ['reads an input stream and converts it to a string .'],
#  8616: ['construct a vector with preset values .'],
#  8617: ['unregister a transaction service listener .'],
#  8618: ['used to communicate a progress update between a plugin tool and the '
#         'main whitebox user interface .'],
#  8619: ['pushes a new type onto the output frame stack .'],
#  8620: ['perform an ort factorization construction .'],
#  8621: ['tests session classes being consistent .'],
#  8622: ['called when an object has been added to the beancontext , and when '
#         'new objects are added to the beancontext after that .'],
#  8623: ['removes all the layers from the widget .'],
#  8624: ['returns the number of productions contained in this rule .'],
#  8625: ['asynchronously create zookeeper path recursively and optim istically '
#         '.'],
#  8626: ['this is the default implementation of writeobject . customize if '
#         'necessary .'],
#  8627: ['compares two money objects for equality with the specified object'],
#  8628: ['this method was generated by mybatis generator . this method '
#         'corresponds to the database table address'],
#  8629: ['obtains an instance due to a given field and field name .'],
#  8630: ['processes an event to the event domain .'],
#  8631: ['unregisters a membership listener'],
#  8632: ['add a message to the given resolver .'],
#  8633: ['present the final image on the screen / viewport .'],
#  8634: ['decrement a calendar by one day .'],
#  8635: ['angular object client bind method .'],
#  8636: ['removes all objects in the given list from the given list . '
#         'afterwards , if the list is modified modified to the remove ( ) '
#         'method .'],
#  8637: ['creates a new project tree object .'],
#  8638: ['determine if the expression is an object .'],
#  8639: ['use interpolator to get t'],
#  8640: ['automatically disconnects the auto - request mods channels .'],
#  8641: ['calculate all objecttype based on current dynamic query'],
#  8642: ['iterates over all values and returns true if one value matches . also '
#         'see contains within bounds .'],
#  8643: ['rename a file . the new row will be replaced by the catalog .'],
#  8644: ['check for the next record in the data source .'],
#  8645: ['first stage the error , then display the exception message and exit '
#         'code . then exit code with an error message from running vm . if exit '
#         'code is null , then exit code is rolled back to exit code .'],
#  8646: ['remove the specified sensor from this sensor selection model .'],
#  8647: ['prints one way at a given point .'],
#  8648: ['returns a string representation of the data row .'],
#  8649: ['create a path from the given object'],
#  8650: ["returns true if there ' s another proxy to try ."],
#  8651: ['checks whether no object has been clicked on on a node'],
#  8652: ['this operation is not supported because pictures are mutable .'],
#  8653: ['sets the resource bundle mappings .'],
#  8654: ["given the location of the ' middle snake ' , split the diff in two "
#         'parts and recurse .'],
#  8655: ['validate credit card number string'],
#  8656: ['create a zip file , if it does not exist . the output directory may '
#         'be a simple file .'],
#  8657: ['instantiates a new config .'],
#  8658: ['creates ll new form goto line dialog'],
#  8659: ['attempts to prepare the request for a retry . if there are no more '
#         "attempts remaining in the request ' s retry policy , a timeout "
#         'exception is thrown .'],
#  8660: ['sets up the y - axis labels . computes the desired number of labels '
#         'between the two given extre mes . unlike the pap arex labels ( ) '
#         'method , this method needs to be called upon every refresh of the '
#         'view .'],
#  8661: ['for ges and sends the teardown request'],
#  8662: ['if this is the first time calling this method , the buffer will be '
#         'checked to make sure it starts with so i marker ( x ff d 8 ) . if the '
#         'image has been identified as a non - jpeg , data will be ignored and '
#         'false will'],
#  8663: ['test deploying a simple ear .'],
#  8664: ['returns the length of this character sequence .'],
#  8665: ['override this method to match based solely on the two prefix objects '
#         '.'],
#  8666: ['notify c + + controller that a wifi monitor has been registered'],
#  8667: ['checks whether value exists for array key'],
#  8668: ['removes the given listener from the list of diagram change listeners '
#         '.'],
#  8669: ['creates a new connectivity factory .'],
#  8670: ['strip leading and trailing whitespace'],
#  8671: ['clears the " host context " system property'],
#  8672: ['constructs an empty marker .'],
#  8673: ['put the separator to the end of the program window .'],
#  8674: ['creates a chart and displays it in the wizard .'],
#  8675: ['returns a buffer to the pool , throwing away old buffers if the pool '
#         'would exceed its allo tted size .'],
#  8676: ['accepts a data point'],
#  8677: ['merges this named range all elements from another named range into '
#         'this named range .'],
#  8678: ['support for get paren tof node ; walks a dom tree until it finds the '
#         'element which owns the attr . this is hu ge ly expensive , and if at '
#         'all possible you should use get paren tof ( ) instead .'],
#  8679: ['creates and starts a tail er for the given file .'],
#  8680: ['is operating system os / 2 ?'],
#  8681: ['returns the number of elements in this array .'],
#  8682: ['creates new d view asn 1 dump dialog where the parent is a dialog .'],
#  8683: ['right trim a string .'],
#  8684: ['put an object in the buffer'],
#  8685: ['dispose - free resources'],
#  8686: ['the result will be positive , if the line is on the left of p point '
#         'else negative .'],
#  8687: ['expands the given number string as a real number .'],
#  8688: ['l - empirical joint matrix .'],
#  8689: ['submits a requests for a set of permissions for an activity .'],
#  8690: ['tell the user of an error , and probably throw an exception .'],
#  8691: ['test the configuration for a wrong property .'],
#  8692: ['creates a new instance of init logger'],
#  8693: ['creates a new delete - xxx sub - command for an instantiable relation '
#         '.'],
#  8694: ['subclasses can override this method to register cycles that are no '
#         'longer visited . it will then remove cycles from the graph . it will '
#         'then be called when calculating the cycles from a way that is based '
#         'on the current graph .'],
#  8695: ['returns a string representation of the given matrix .'],
#  8696: ["given a ' from ' pattern ( ala xsl : number ) , a match pattern and a "
#         'context , find the first ancestor that matches the pattern ( '
#         'including the namespace handed in ) .'],
#  8697: ['kill the store and destroy the encrypted subscription .'],
#  8698: ['this is a facade method for the encoding operation . this method '
#         'encodes the remaining character sequence of the given character '
#         'buffer into a new byte buffer . this method performs a complete '
#         'encoding operation , resets at first , then encodes , and flushes at '
#         'last . this method'],
#  8699: ['a utility method that creates a metric object .'],
#  8700: ['resolves a class using org . apache . commons . lang . string '
#         'operation ( if available ) .'],
#  8701: ['instances should not be constructed in standard programming .'],
#  8702: ['returns true if the given point is part of the report .'],
#  8703: ['inserts a byte array']}
